# %%
import csv
import googletrans

row = []
# Import the CSV file
with open("af.csv", "r") as csvfile:
    reader = csv.reader(csvfile, delimiter=",")

    # Create a translator object
    translator = googletrans.Translator()

    # Iterate over the rows in the CSV file
    for i,row in enumerate(reader):
        # Get the English word from the first column
        english_word = row[0]

        # Translate the English word to Mongolian
        mongolian_translation = translator.translate(english_word, dest="mn")

        # Add the Mongolian translation to the second column
        row[1] =(mongolian_translation.text)
        print(i/9905)
        print(row)

        # Write the updated CSV file
        with open("new-hr.csv", "a", newline="") as csvfile:
            writer = csv.writer(csvfile, delimiter=",", escapechar="\\")
            writer.writerow(row)
# Out:
# 0.0
# [') for {0}', ') {0}-д', '']
# 0.00010095911155981827
# ['A {0} exists between {1} and {2} (', '{1} болон {2} хооронд {0} байна (', '']
# 0.00020191822311963655
# ['Absent', 'Байхгүй', '']
# 0.00030287733467945484
# ['Accrual Journal Entry for salaries from {0} to {1}', '{0}-с {1} хүртэлх цалингийн аккруэл журналын бичилт', '']
# 0.0004038364462392731
# ['Add to Details', 'Дэлгэрэнгүй мэдээлэлд нэмнэ үү', '']
# 0.0005047955577990914
# ['Added to details', 'Дэлгэрэнгүй мэдээлэлд нэмсэн', '']
# 0.0006057546693589097
# ['All Jobs', 'Бүх ажлын байр', '']
# 0.0007067137809187279
# ['Allocated Leaves', 'Хуваарилагдсан навч', '']
# 0.0008076728924785462
# ['Annual Salary', 'Жилийн цалин', '']
# 0.0009086320040383645
# ['Application period cannot be across two allocation records', 'Өргөдөл гаргах хугацаа нь хоёр хуваарилалтын бүртгэлд байж болохгүй', '']
# 0.0010095911155981827
# ['Application period cannot be outside leave allocation period', 'Өргөдөл гаргах хугацаа нь чөлөө олгох хугацаанаас гадуур байж болохгүй', '']
# 0.001110550227158001
# ['Apply Now', 'Одоо хэрэгжүүлэх', '']
# 0.0012115093387178194
# ['Apprentice', 'Дагалдан', '']
# 0.0013124684502776375
# ['Approval Status', 'Зөвшөөрлийн статус', '']
# 0.0014134275618374558
# ["Approval Status must be 'Approved' or 'Rejected'", 'Зөвшөөрлийн статус нь "Батлагдсан" эсвэл "Татгалзсан" байх ёстой', '']
# 0.001514386673397274
# ['Approve', 'Зөвшөөрөх', '']
# 0.0016153457849570924
# ['As per your assigned Salary Structure you cannot apply for benefits', 'Таны томилсон Цалингийн бүтцийн дагуу та тэтгэмж авах хүсэлт гаргах боломжгүй', '']
# 0.0017163048965169107
# ['Assign', 'Даалгах', '']
# 0.001817264008076729
# ['Assign Salary Structure', 'Цалингийн бүтцийг томилох', '']
# 0.0019182231196365471
# ['Assign to Employees', 'Ажилчдад хуваарилах', '']
# 0.0020191822311963654
# ['Assigning Structures...', 'Бүтцийг оноож байна...', '']
# 0.0021201413427561835
# ['Attendance', 'Ирц', '']
# 0.002221100454316002
# ['Attendance From Date and Attendance To Date is mandatory', 'Огнооноос өнөөг хүртэлх ирц заавал байх ёстой', '']
# 0.00232205956587582
# ['Attendance for employee {0} is already marked for this day', '{0} ажилтны ирцийг энэ өдөр аль хэдийн тэмдэглэсэн байна', '']
# 0.0024230186774356387
# ['Attendance not submitted for {0} as it is a Holiday.', 'Амралтын өдөр тул {0}-д ирц ирүүлээгүй.', '']
# 0.002523977788995457
# ['Bank Entries', 'Банкны бүртгэл', '']
# 0.002624936900555275
# ['Base', 'Суурь', '']
# 0.0027258960121150934
# ['Beginner', 'Эхлэгч', '']
# 0.0028268551236749115
# ['Birthday Reminder', 'Төрсөн өдрийн сануулга', '']
# 0.00292781423523473
# ['Bonus Payment Date cannot be a past date', 'Бонус төлөх огноо нь өнгөрсөн огноо байж болохгүй', '']
# 0.003028773346794548
# ['Calls', 'Дуудлага', '']
# 0.0031297324583543663
# ['Cannot find active Leave Period', 'Идэвхтэй чөлөө авах хугацааг олж чадсангүй', '']
# 0.003230691569914185
# ['Casual Leave', 'Энгийн чөлөө', '']
# 0.003331650681474003
# ['Claimed Amount', 'Нэхэмжлэгдсэн дүн', '']
# 0.0034326097930338214
# ['Compensatory Off', 'Нөхөн олговрыг унтраах', '']
# 0.0035335689045936395
# ['Contact Number', 'Холбогдох дугаар', '']
# 0.003634528016153458
# ['Course', 'Мэдээж', '']
# 0.003735487127713276
# ['Create Disbursement Entry', 'Төлбөрийн бүртгэл үүсгэх', '']
# 0.0038364462392730943
# ['Create Salary Slip', 'Цалингийн хуудас үүсгэх', '']
# 0.003937405350832913
# ['Create Salary Slips', 'Цалингийн хуудас үүсгэх', '']
# 0.004038364462392731
# ['Creating Payment Entries......', 'Төлбөрийн бичилт үүсгэж байна......', '']
# 0.004139323573952549
# ['Creating Salary Slips...', 'Цалингийн хуудас үүсгэж байна...', '']
# 0.004240282685512367
# ['Current', 'Одоогийн', '']
# 0.004341241797072186
# ['Current Job Openings', 'Одоогийн нээлттэй ажлын байр', '']
# 0.004442200908632004
# ['Daily Work Summary', 'Өдөр тутмын ажлын хураангуй', '']
# 0.004543160020191822
# ['Daily Work Summary Group', 'Өдөр тутмын ажлын тойм бүлэг', '']
# 0.00464411913175164
# ['Date is repeated', 'Огноо давтагдана', '']
# 0.0047450782433114585
# ['Debit A/C Number', 'Дебит A/C дугаар', '']
# 0.004846037354871277
# ['Deduction', 'Суутгал', '']
# 0.0049469964664310955
# ['Document Status', 'Баримт бичгийн төлөв', '']
# 0.005047955577990914
# ['Earning', 'Орлого', '']
# 0.005148914689550732
# ['Employee A/C Number', 'Ажилтны A/C дугаар', '']
# 0.00524987380111055
# ['Employee Benefits', 'Ажилчдын тэтгэмж', '']
# 0.005350832912670369
# ['Employee Grade', 'Ажилтны зэрэг', '']
# 0.005451792024230187
# ['Employee Referral', 'Ажилтаны лавлагаа', '']
# 0.005552751135790005
# ["Employee relieved on {0} must be set as 'Left'", '{0}-д чөлөөлөгдсөн ажилтныг "Зүүн" гэж тохируулах ёстой', '']
# 0.005653710247349823
# ['Employee {0} already submited an apllication {1} for the payroll period {2}', 'Ажилтан {0} аль хэдийн {2} цалингийн хугацаанд {1} өргөдлөө өгсөн байна', '']
# 0.005754669358909641
# ['Employee {0} has no maximum benefit amount', '{0} ажилтанд тэтгэмжийн дээд хэмжээ байхгүй', '']
# 0.00585562847046946
# ['Employee {0} is not active or does not exist', 'Ажилтан {0} идэвхгүй эсвэл байхгүй байна', '']
# 0.005956587582029278
# ['Employee {0} is on Leave on {1}', 'Ажилтан {0} {1}-д амарна', '']
# 0.006057546693589096
# ['Employee {0} on Half day on {1}', 'Ажилтан {0} хагас өдөр {1}', '']
# 0.0061585058051489144
# ['End time cannot be before start time', 'Дуусах цаг нь эхлэх цагаас өмнө байж болохгүй', '']
# 0.0062594649167087325
# ['Evaluation', 'Үнэлгээ', '']
# 0.0063604240282685515
# ['Event Location', 'Үйл явдлын байршил', '']
# 0.00646138313982837
# ['Event Name', 'Үйл явдлын нэр', '']
# 0.006562342251388188
# ['Expense Claim for Vehicle Log {0}', 'Тээврийн хэрэгслийн бүртгэлийн зардлын нэхэмжлэл {0}', '']
# 0.006663301362948006
# ['Expense Claim {0} already exists for the Vehicle Log', 'Тээврийн хэрэгслийн бүртгэлд зардлын нэхэмжлэл {0} байна', '']
# 0.006764260474507825
# ['Fill the form and save it', 'Маягтыг бөглөж хадгална уу', '']
# 0.006865219586067643
# ['Filter Employees By (Optional)', 'Ажилчдыг шүүх (заавал биш)', '']
# 0.006966178697627461
# ['Fiscal Year {0} not found', 'Санхүүгийн жил {0} олдсонгүй', '']
# 0.007067137809187279
# ['Food', 'Хоол хүнс', '']
# 0.007168096920747097
# ['For Employee', 'Ажилтны хувьд', '']
# 0.007269056032306916
# ["From Date {0} cannot be after employee's relieving Date {1}", 'Ажилтан чөлөөлөгдсөн огноо {1}-ээс хойш {0} байх боломжгүй.', '']
# 0.007370015143866734
# ["From Date {0} cannot be before employee's joining Date {1}", 'Огнооноос {0} нь ажилтны нэгдсэн огноо {1}-ээс өмнө байж болохгүй', '']
# 0.007470974255426552
# ["From date can not be less than employee's joining date", 'Энэ өдрөөс эхлэн ажилтны нэгдсэн өдрөөс бага байж болохгүй', '']
# 0.00757193336698637
# ['Fuel Price', 'Шатахууны үнэ', '']
# 0.0076728924785461885
# ['Fuel Qty', 'Шатахууны тоо', '']
# 0.0077738515901060075
# ['Full-time', 'Бүтэн цагийн', '']
# 0.007874810701665826
# ['Future dates not allowed', 'Ирээдүйн огноог зөвшөөрөхгүй', '']
# 0.007975769813225644
# ['Get Details From Declaration', 'Тунхаглалаас дэлгэрэнгүй мэдээлэл аваарай', '']
# 0.008076728924785462
# ['Get Employees', 'Ажилчдыг авах', '']
# 0.00817768803634528
# ['Gross Pay', 'Нийт цалин', '']
# 0.008278647147905098
# ['Guest', 'Зочин', '']
# 0.008379606259464916
# ['Half Day', 'Хагас өдөр', '']
# 0.008480565371024734
# ['Half Day Date is mandatory', 'Хагас өдрийн огноо нь заавал байх ёстой', '']
# 0.008581524482584554
# ['Half Day Date should be between From Date and To Date', 'Хагас өдрийн огноо нь огнооноос өнөөг хүртэлх хооронд байх ёстой', '']
# 0.008682483594144372
# ['Half Day Date should be in between Work From Date and Work End Date', 'Хагас өдрийн огноо нь ажлын өдрөөс хойш, ажил дуусах огнооны хооронд байх ёстой', '']
# 0.00878344270570419
# ['Half day date should be in between from date and to date', 'Хагас өдрийн огноо нь өдрөөс хойш өнөөг хүртэл байх ёстой', '']
# 0.008884401817264008
# ['Hello', 'Сайн уу', '']
# 0.008985360928823826
# ['House rent paid days overlapping with {0}', 'Байрны түрээсийн төлбөртэй өдрүүд {0}-тэй давхцаж байна', '']
# 0.009086320040383645
# ['House rented dates required for exemption calculation', 'Чөлөөлөлтийг тооцоход шаардлагатай байшин түрээслэх хугацаа', '']
# 0.009187279151943463
# ['House rented dates should be atleast 15 days apart', 'Байшин түрээслэх хугацаа нь дор хаяж 15 хоногийн зайтай байх ёстой', '']
# 0.00928823826350328
# ['Interest Amount', 'Хүүгийн хэмжээ', '']
# 0.009389197375063099
# ['Intern', 'Дадлагажигч', '']
# 0.009490156486622917
# ['Job Description', 'Ажлын байрны тодорхойлолт', '']
# 0.009591115598182737
# ['Job Offer', 'Ажлын санал', '']
# 0.009692074709742555
# ['Jobs', 'Ажлын байр', '']
# 0.009793033821302373
# ['Leave Approval Notification', 'Зөвшөөрлийн мэдэгдлийг үлдээх', '']
# 0.009893992932862191
# ['Leave Blocked', 'Блоклосон орхи', '']
# 0.009994952044422009
# ['Leave Encashment', 'Бэлэн мөнгө үлдээх', '']
# 0.010095911155981827
# ['Leave Status Notification', 'Статусын мэдэгдлийг орхи', '']
# 0.010196870267541645
# ['Leave Type', 'Орхих төрөл', '']
# 0.010297829379101463
# ['Leave Type is madatory', 'Амрах төрөл заавал байх ёстой', '']
# 0.010398788490661282
# ['Leave Type {0} cannot be allocated since it is leave without pay', 'Амралтын төрөл {0} нь цалингүй чөлөө тул хуваарилах боломжгүй', '']
# 0.0104997476022211
# ['Leave Type {0} cannot be carry-forwarded', 'Амралтын төрлийг {0} шилжүүлэх боломжгүй', '']
# 0.01060070671378092
# ['Leave Type {0} is not encashable', 'Орхих төрөл {0} мөнгө шилжүүлэх боломжгүй', '']
# 0.010701665825340738
# ['Leave Without Pay', 'Төлбөргүй орхи', '']
# 0.010802624936900556
# ['Leave cannot be allocated before {0}, as leave balance has already been carry-forwarded in the future leave allocation record {1}', 'Ирээдүйн амралтын хуваарилалтын бүртгэлд амралтын үлдэгдэл аль хэдийн шилжсэн тул {0}-ээс өмнө чөлөө олгох боломжгүй. {1}', '']
# 0.010903584048460374
# ['Leave cannot be applied/cancelled before {0}, as leave balance has already been carry-forwarded in the future leave allocation record {1}', 'Ирээдүйн амралтын хуваарилалтын бүртгэлд амралтын үлдэгдэл аль хэдийн шилжсэн тул {0}-ээс өмнө чөлөө олгох/цуцлах боломжгүй {1}', '']
# 0.011004543160020192
# ['Leave of type {0} cannot be longer than {1}', '{0} төрлийн чөлөө нь {1}-ээс урт байж болохгүй', '']
# 0.01110550227158001
# ['Leaves', 'Навч', '']
# 0.011206461383139828
# ['Leaves Allocated Successfully for {0}', 'Навчийг {0}-д амжилттай хуваариллаа', '']
# 0.011307420494699646
# ['Leaves per Year', 'Жилд навч', '']
# 0.011408379606259464
# ['Lifecycle', 'Амьдралын мөчлөг', '']
# 0.011509338717819282
# ['Mark Attendance', 'Ирцийг тэмдэглэ', '']
# 0.011610297829379102
# ['Max Exemption Amount cannot be greater than maximum exemption amount {0} of Tax Exemption Category {1}', 'Чөлөөлөлтийн дээд хэмжээ нь {1} Татвараас чөлөөлөх ангиллын {0}-аас ихгүй байж болохгүй.', '']
# 0.01171125694093892
# ['Max benefits should be greater than zero to dispense benefits', 'Тэтгэмж олгохын тулд тэтгэмжийн дээд хэмжээ тэгээс их байх ёстой', '']
# 0.011812216052498738
# ['Maximum amount eligible for the component {0} exceeds {1}', '{0} бүрэлдэхүүнд тохирох дээд хэмжээ {1}-ээс хэтэрсэн байна', '']
# 0.011913175164058556
# ['Maximum benefit amount of component {0} exceeds {1}', '{0} бүрэлдэхүүн хэсгийн ашиг тусын дээд хэмжээ {1}-ээс хэтэрсэн байна', '']
# 0.012014134275618375
# ['Maximum benefit amount of employee {0} exceeds {1}', 'Ажилтны тэтгэмжийн дээд хэмжээ {0} {1}-ээс хэтэрсэн байна', '']
# 0.012115093387178193
# ['Maximum leave allowed in the leave type {0} is {1}', 'Амралтын төрөлд зөвшөөрөгдөх дээд хэмжээ {0} нь {1}', '']
# 0.01221605249873801
# ['Medical', 'Анагаах ухаан', '']
# 0.012317011610297829
# ['Mode of payment is required to make a payment', 'Төлбөр хийхдээ төлбөрийн хэлбэр шаардлагатай', '']
# 0.012417970721857647
# ['More than one selection for {0} not allowed', '{0}-н нэгээс олон сонголтыг зөвшөөрөхгүй', '']
# 0.012518929833417465
# ['Net Pay', 'Цэвэр төлбөр', '']
# 0.012619888944977285
# ['Net Pay cannot be less than 0', 'Цэвэр төлбөр 0-ээс бага байж болохгүй', '']
# 0.012720848056537103
# ['Net Salary Amount', 'Цалингийн цэвэр дүн', '']
# 0.012821807168096921
# ['Net pay cannot be negative', 'Цэвэр цалин сөрөг байж болохгүй', '']
# 0.01292276627965674
# ['No Employee Found', 'Ажилтан олдсонгүй', '']
# 0.013023725391216557
# ['No Salary Structure assigned for Employee {0} on given date {1}', 'Өгөгдсөн {1} өдөр {0} ажилтны цалингийн бүтцийг томилоогүй', '']
# 0.013124684502776375
# ['No Staffing Plans found for this Designation', 'Энэ томилгоонд ажиллах боловсон хүчний төлөвлөгөө олдсонгүй', '']
# 0.013225643614336193
# ['No active or default Salary Structure found for employee {0} for the given dates', 'Өгөгдсөн өдрүүдэд {0} ажилтны идэвхтэй эсвэл өгөгдмөл цалингийн бүтэц олдсонгүй', '']
# 0.013326602725896012
# ['No more updates', 'Өөр шинэчлэлт байхгүй', '']
# 0.01342756183745583
# ['No replies from', '-аас хариу алга', '']
# 0.01352852094901565
# ['No salary slip found to submit for the above selected criteria OR salary slip already submitted', 'Дээрх сонгосон шалгуурын дагуу өгөх цалингийн хуудас олдсонгүй ЭСВЭЛ аль хэдийн ирүүлсэн цалингийн хуудас', '']
# 0.013629480060575468
# ['Nothing to change', 'Өөрчлөх зүйл алга', '']
# 0.013730439172135286
# ['Notice Period', 'Халагдах хугацаа', '']
# 0.013831398283695104
# ["Only Leave Applications with status 'Approved' and 'Rejected' can be submitted", 'Зөвхөн "Зөвшөөрсөн" болон "Татгалзсан" статустай өргөдлийг үлдээх боломжтой', '']
# 0.013932357395254922
# ['Optional Holiday List not set for leave period {0}', 'Амралтын өдрийн жагсаалтыг {0}-д тохируулаагүй', '']
# 0.01403331650681474
# ['Part-time', 'Хагас цагийн', '']
# 0.014134275618374558
# ['Password policy for Salary Slips is not set', 'Цалингийн хуудасны нууц үгийн бодлогыг тохируулаагүй байна', '']
# 0.014235234729934376
# ['Payment Days', 'Төлбөрийн өдрүүд', '']
# 0.014336193841494194
# ['Payment of {0} from {1} to {2}', '{1}-с {2} хүртэлх {0}-н төлбөр', '']
# 0.014437152953054012
# ['Payroll', 'Цалин', '']
# 0.014538112064613832
# ['Payroll Number', 'Цалингийн дугаар', '']
# 0.01463907117617365
# ['Piecework', 'Хэсэгчилсэн ажил', '']
# 0.014740030287733468
# ['Please add the remaining benefits {0} to any of the existing component', 'Үлдсэн үр өгөөжийг {0} одоо байгаа аль нэг бүрэлдэхүүн хэсэгт нэмнэ үү', '']
# 0.014840989399293287
# ['Please confirm once you have completed your training', 'Сургалтаа дуусгасны дараа баталгаажуулна уу', '']
# 0.014941948510853105
# ['Please enable default incoming account before creating Daily Work Summary Group', 'Өдөр тутмын ажлын хураангуй бүлгийг үүсгэхээсээ өмнө өгөгдмөл ирсэн бүртгэлийг идэвхжүүлнэ үү', '']
# 0.015042907622412923
# ['Please select Company and Designation', 'Компани болон нэрийг сонгоно уу', '']
# 0.01514386673397274
# ['Please select Employee', 'Ажилтнаа сонгоно уу', '']
# 0.015244825845532559
# ['Please select a csv file', 'csv файл сонгоно уу', '']
# 0.015345784957092377
# ['Please set default template for Leave Approval Notification in HR Settings.', 'Хүний нөөцийн тохиргоонд зөвшөөрөл олгох мэдэгдлийн өгөгдмөл загварыг тохируулна уу.', '']
# 0.015446744068652195
# ['Please set default template for Leave Status Notification in HR Settings.', 'Хүний нөөцийн тохиргоонд Орхих статусын мэдэгдлийн өгөгдмөл загварыг тохируулна уу.', '']
# 0.015547703180212015
# ['Please set the Company', 'Компанийг тохируулна уу', '']
# 0.015648662291771833
# ['Please set the Date Of Joining for employee {0}', 'Ажилтан {0}-д элссэн огноог тохируулна уу', '']
# 0.01574962140333165
# ["Please share your feedback to the training by clicking on 'Training Feedback' and then 'New'", 'Сургалтын талаарх санал хүсэлтээ "Сургалтын санал хүсэлт" дээр дараад "Шинэ" дээр дарж хуваалцана уу.', '']
# 0.01585058051489147
# ['Please update your status for this training event', 'Энэхүү сургалтын арга хэмжээний статусаа шинэчилнэ үү', '']
# 0.015951539626451287
# ['Present', 'Одоо байна', '']
# 0.016052498738011105
# ['Preview Salary Slip', 'Цалингийн хуудсыг урьдчилан үзэх', '']
# 0.016153457849570924
# ['Privilege Leave', 'Давуу эрх чөлөө', '']
# 0.01625441696113074
# ['Probation', 'Туршилт', '']
# 0.01635537607269056
# ['Probationary Period', 'Туршилтын хугацаа', '']
# 0.016456335184250378
# ['Property', 'Өмч', '']
# 0.016557294295810196
# ['Property already added', 'Өмчийг аль хэдийн нэмсэн', '']
# 0.016658253407370014
# ['Reject', 'Татгалзах', '']
# 0.016759212518929832
# ['Replies', 'Хариултууд', '']
# 0.01686017163048965
# ['Responsibilities', 'Хариуцлага', '']
# 0.01696113074204947
# ['Role', 'Үүрэг', '']
# 0.01706208985360929
# ['Row {0}# Allocated amount {1} cannot be greater than unclaimed amount {2}', 'Мөр {0}# Хуваарилагдсан дүн {1} нэхэмжлээгүй дүнгээс {2} их байж болохгүй', '']
# 0.017163048965169108
# ['Row {0}# Paid Amount cannot be greater than requested advance amount', 'Мөр {0}# Төлсөн дүн нь хүссэн урьдчилгаа дүнгээс их байж болохгүй', '']
# 0.017264008076728926
# ['Salary Slip ID', 'Цалингийн хуудасны үнэмлэх', '']
# 0.017364967188288744
# ['Salary Slip of employee {0} already created for this period', 'Энэ хугацаанд аль хэдийн үүсгэсэн {0} ажилтны цалингийн хуудас', '']
# 0.017465926299848562
# ['Salary Slip of employee {0} already created for time sheet {1}', 'Ажилтны {0} цалингийн хуудас {1} цагийн хуваарьт зориулж аль хэдийн үүсгэсэн', '']
# 0.01756688541140838
# ['Salary Structure Assignment for Employee already exists', 'Ажилтны цалингийн бүтцийн хуваарилалт аль хэдийн байна', '']
# 0.0176678445229682
# ['Salary Structure Missing', 'Цалингийн бүтэц дутуу байна', '']
# 0.017768803634528017
# ['Salary Structure not found for employee {0} and date {1}', '{0} ажилтны цалингийн бүтэц, огноо {1} олдсонгүй', '']
# 0.017869762746087835
# ['Salary Structure should have flexible benefit component(s) to dispense benefit amount', 'Цалингийн бүтэц нь тэтгэмжийн хэмжээг олгох уян хатан тэтгэмжийн бүрэлдэхүүн хэсгүүдтэй байх ёстой', '']
# 0.017970721857647653
# ['Salary already processed for period between {0} and {1}, Leave application period cannot be between this date range.', '{0}-с {1} хүртэлх хугацааны цалинг аль хэдийн боловсруулсан, чөлөө авах өргөдөл гаргах хугацаа энэ хугацааны хооронд байж болохгүй.', '']
# 0.01807168096920747
# ['Sanctioned Amount cannot be greater than Claim Amount in Row {0}.', 'Шийдвэрлэсэн дүн нь {0} мөрийн нэхэмжлэлийн дүнгээс их байж болохгүй.', '']
# 0.01817264008076729
# ['Score must be less than or equal to 5', 'Оноо 5-аас бага буюу тэнцүү байх ёстой', '']
# 0.018273599192327107
# ['Select Property', 'Property сонгоно уу', '']
# 0.018374558303886925
# ['Select an employee to get the employee advance.', 'Ажилтны урьдчилгааг авахын тулд ажилтнаа сонго.', '']
# 0.018475517415446743
# ['Service Expense', 'Үйлчилгээний зардал', '']
# 0.01857647652700656
# ['Show Employee', 'Ажилчдыг харуулах', '']
# 0.01867743563856638
# ['Show Salary Slip', 'Цалингийн хуудас харуулах', '']
# 0.018778394750126198
# ['Sick Leave', 'Өвчний чөлөө', '']
# 0.018879353861686016
# ['Skipping Salary Structure Assignment for the following employees, as Salary Structure Assignment records already exists against them. {0}', 'Дараах ажилтнуудын цалингийн бүтцийн хуваарилалт тэдний эсрэг аль хэдийн байгаа тул цалингийн бүтцийн хуваарилалтыг алгасаж байна. {0}', '']
# 0.018980312973245834
# ['Staffing Plan {0} already exist for designation {1}', 'Ажилтны төлөвлөгөө {0} нь {1}-д зориулагдсан', '']
# 0.019081272084805655
# ['Start and end dates not in a valid Payroll Period, cannot calculate {0}', 'Эхлэх болон дуусах огноо нь хүчинтэй цалингийн хугацаанд биш, {0}-г тооцоолох боломжгүй', '']
# 0.019182231196365473
# ['Start and end dates not in a valid Payroll Period, cannot calculate {0}.', 'Эхлэх болон дуусах огноо нь хүчинтэй цалингийн хугацаанд биш, {0}-г тооцох боломжгүй.', '']
# 0.01928319030792529
# ['Stock Options', 'Хувьцааны сонголтууд', '']
# 0.01938414941948511
# ['Structures have been assigned successfully', 'Бүтцүүдийг амжилттай томилсон', '']
# 0.019485108531044928
# ['Submit Proof', 'Нотлох баримт илгээх', '']
# 0.019586067642604746
# ['Submit Salary Slip', 'Цалингийн хуудас өгөх', '']
# 0.019687026754164564
# ['Submit this to create the Employee record', 'Ажилтны бүртгэлийг үүсгэхийн тулд үүнийг илгээнэ үү', '']
# 0.019787985865724382
# ['Submitting Salary Slips...', 'Цалингийн хуудас илгээж байна...', '']
# 0.0198889449772842
# ['Team Updates', 'Багийн шинэчлэлтүүд', '']
# 0.019989904088844018
# ['Thank you', 'Баярлалаа', '']
# 0.020090863200403836
# ['The day(s) on which you are applying for leave are holidays. You need not apply for leave.', 'Таны чөлөө авах хүсэлт гаргаж буй өдөр(үүд) нь амралтын өдрүүд юм. Та чөлөө авах хүсэлт гаргах шаардлагагүй.', '']
# 0.020191822311963654
# ['There are more holidays than working days this month.', 'Энэ сард ажлын өдрүүдээс олон амралтын өдрүүд тохиож байна.', '']
# 0.020292781423523473
# ['There is no leave period in between {0} and {1}', '{0}-с {1} хооронд амралтын хугацаа байхгүй', '']
# 0.02039374053508329
# ['This is based on the attendance of this Employee', 'Энэ нь тухайн ажилтны ирц дээр үндэслэсэн болно', '']
# 0.02049469964664311
# ['This will submit Salary Slips and create accrual Journal Entry. Do you want to proceed?', 'Энэ нь Цалингийн хуудсаа илгээж, аккруэл журналын бичилт үүсгэх болно. Та үргэлжлүүлэхийг хүсэж байна уу?', '']
# 0.020595658758202927
# ['To date can not be equal or less than from date', 'Өнөөдрийг хүртэл огноотой тэнцүү эсвэл бага байж болохгүй', '']
# 0.020696617869762745
# ['To date can not be less than from date', 'Өнөөдрийг хүртэл огнооноос бага байж болохгүй', '']
# 0.020797576981322563
# ["To date can not greater than employee's relieving date", 'Өнөөдрийг хүртэл ажилтны чөлөөлөгдсөн өдрөөс хэтрэхгүй байх ёстой', '']
# 0.02089853609288238
# ['Total Absent', 'Нийт байхгүй', '']
# 0.0209994952044422
# ['Total Deduction', 'Нийт хасалт', '']
# 0.02110045431600202
# ['Total Leaves', 'Нийт навч', '']
# 0.02120141342756184
# ['Total Present', 'Нийт одоогийн', '']
# 0.021302372539121657
# ['Total advance amount cannot be greater than total sanctioned amount', 'Урьдчилгаа нийт хэмжээ зөвшөөрөгдсөн нийт дүнгээс их байж болохгүй', '']
# 0.021403331650681475
# ['Total flexible benefit component amount {0} should not be less than max benefits {1}', 'Уян хатан тэтгэмжийн бүрэлдэхүүн хэсгийн нийт дүн {0} нь хамгийн их ашиг {1}-ээс бага байж болохгүй.', '']
# 0.021504290762241293
# ['Total leaves allocated is mandatory for Leave Type {0}', 'Амралтын төрөл {0}-д хуваарилагдсан нийт навч заавал байх ёстой.', '']
# 0.02160524987380111
# ['Total working hours should not be greater than max working hours {0}', 'Ажлын нийт цаг хамгийн их ажлын цагаас хэтрэхгүй байх ёстой {0}', '']
# 0.02170620898536093
# ['Training', 'Сургалт', '']
# 0.021807168096920748
# ['Training Event', 'Сургалтын арга хэмжээ', '']
# 0.021908127208480566
# ['Training Events', 'Сургалтын арга хэмжээ', '']
# 0.022009086320040384
# ['Training Feedback', 'Сургалтын санал хүсэлт', '']
# 0.022110045431600202
# ['Training Result', 'Сургалтын үр дүн', '']
# 0.02221100454316002
# ['Travel', 'Аялал', '']
# 0.022311963654719838
# ['Update Response', 'Хариуг шинэчлэх', '']
# 0.022412922766279656
# ['Value missing', 'Утга дутуу байна', '']
# 0.022513881877839474
# ['Variable', 'Хувьсагч', '']
# 0.022614840989399292
# ['Walk In', 'Орох', '']
# 0.02271580010095911
# ['Warning: Leave application contains following block dates', 'Анхааруулга: Өргөдөл гаргах нь дараах блок огноог агуулна', '']
# 0.02281675921251893
# ['Website Listing', 'Вэб сайтын жагсаалт', '']
# 0.022917718324078747
# ['Work Summary for {0}', '{0}-н ажлын хураангуй', '']
# 0.023018677435638565
# ['You are not authorized to approve leaves on Block Dates', 'Та Блокны огнооны навчийг зөвшөөрөх эрхгүй', '']
# 0.023119636547198386
# ['You are not present all day(s) between compensatory leave request days', 'Та нөхөн олговор олгох хүсэлт гаргасан өдрүүдийн хооронд өдөржингөө байхгүй байна', '']
# 0.023220595658758204
# ['You can only submit Leave Encashment for a valid encashment amount', 'Та зөвхөн хүчинтэй мөнгөн дүнгээр чөлөөний мөнгө өгөх боломжтой', '']
# 0.023321554770318022
# ['{0} already allocated for Employee {1} for period {2} to {3}', '{2}-с {3} хүртэлх хугацаанд {1} ажилтанд {0} аль хэдийн хуваарилагдсан байна', '']
# 0.02342251388187784
# ['{0} applicable after {1} working days', '{0} ажлын {1} өдрийн дараа хэрэгжинэ', '']
# 0.02352347299343766
# ['{0} is not in Optional Holiday List', '{0} нэмэлт амралтын жагсаалтад байхгүй', '']
# 0.023624432104997477
# ['{0} is not in a valid Payroll Period', '{0} хүчинтэй цалингийн хугацаанд биш байна', '']
# 0.023725391216557295
# ['{0} must be submitted', '{0} оруулах ёстой', '']
# 0.023826350328117113
# ['{0}: Employee email not found, hence email not sent', '{0}: Ажилтны имэйл олдсонгүй, тиймээс имэйл илгээгээгүй', '']
# 0.02392730943967693
# ['{0}: From {0} of type {1}', '{0}: {1} төрлийн {0}-с', '']
# 0.02402826855123675
# ['Conditions', 'Нөхцөл байдал', '']
# 0.024129227662796567
# ['Percent', 'Хувь', '']
# 0.024230186774356385
# ['Error in some rows', 'Зарим мөрөнд алдаа гарсан', '']
# 0.024331145885916203
# ['Benefit', 'Ашиг тус', '']
# 0.02443210499747602
# ['Shift', 'Шилжилт', '']
# 0.02453306410903584
# ['Importing {0} of {1}', '{1}-с {0}-г импортлож байна', '']
# 0.024634023220595658
# ["'employee_field_value' and 'timestamp' are required.", "'ажилтны_талбайн_үнэ' болон 'цаг хугацааны тамга' шаардлагатай.", '']
# 0.024734982332155476
# ['Allocation Expired!', 'Хуваарилалтын хугацаа дууссан!', '']
# 0.024835941443715294
# ['Attendance Marked', 'Ирцийг тэмдэглэсэн', '']
# 0.024936900555275112
# ['Attendance has been marked as per employee check-ins', 'Ажилчдын бүртгэлд хамрагдсанаар ирцийг тэмдэглэсэн', '']
# 0.02503785966683493
# ['Date Range', 'Огнооны хүрээ', '']
# 0.02513881877839475
# ['Event Link', 'Үйл явдлын холбоос', '']
# 0.02523977788995457
# ['Expire Allocation', 'Хуваарилалтын хугацаа дуусах', '']
# 0.025340737001514388
# ['Fuel Expense', 'Шатахууны зардал', '']
# 0.025441696113074206
# ['Intermediate', 'Дунд зэрэг', '']
# 0.025542655224634024
# ['Leave application is linked with leave allocations {0}. Leave application cannot be set as leave without pay', 'Амралтаас чөлөө авах хүсэлтийг чөлөө олгохтой {0} холбосон. Амрах өргөдлийг цалингүй чөлөө гэж тохируулах боломжгүй', '']
# 0.025643614336193842
# ['Log Type is required for check-ins falling in the shift: {0}.', 'Бүртгэлийн төрөл нь ээлжийн бүртгэлд ороход шаардлагатай: {0}.', '']
# 0.02574457344775366
# ["No Employee found for the given employee field value. '{}': {}", "Өгөгдсөн ажилтны талбарт ямар ч ажилтан олдсонгүй. '{}': {}", '']
# 0.02584553255931348
# ['No Leaves Allocated to Employee: {0} for Leave Type: {1}', 'Ажилтанд ямар ч чөлөө хуваарилагдаагүй: Амралтын төрөлд {0}: {1}', '']
# 0.025946491670873296
# ['Only expired allocation can be cancelled', 'Зөвхөн хугацаа нь дууссан хуваарилалтыг цуцалж болно', '']
# 0.026047450782433115
# ['Only users with the {0} role can create backdated leave applications', 'Зөвхөн {0} үүрэг бүхий хэрэглэгчид буцаагдсан чөлөөний аппликейшн үүсгэх боломжтой', '']
# 0.026148409893992933
# ['Password policy cannot contain spaces or simultaneous hyphens. The format will be restructured automatically', 'Нууц үгийн бодлого нь хоосон зай эсвэл нэгэн зэрэг зураас агуулж болохгүй. Формат автоматаар өөрчлөгдөнө', '']
# 0.02624936900555275
# ['Please enter the designation', 'Тодорхойлолтыг оруулна уу', '']
# 0.02635032811711257
# ['There are no vacancies under staffing plan {0}', 'Ажилтны төлөвлөгөөний дагуу сул орон тоо байхгүй байна {0}', '']
# 0.026451287228672387
# ['This employee already has a log with the same timestamp.{0}', 'Энэ ажилтан аль хэдийн ижил цагийн тэмдэгтэй бүртгэлтэй байна.{0}', '']
# 0.026552246340232205
# ['Timing', 'Хугацаа', '']
# 0.026653205451792023
# ['To date needs to be before from date', 'Өнөөдрийг хүртэл огнооноос өмнө байх шаардлагатай', '']
# 0.02675416456335184
# ['Total Early Exits', 'Нийт эрт гарах', '']
# 0.02685512367491166
# ['Total Late Entries', 'Нийт хоцорсон оруулгууд', '']
# 0.026956082786471477
# ['Training Event:', 'Сургалтын арга хэмжээ:', '']
# 0.0270570418980313
# ['Unable to find Salary Component {0}', 'Цалингийн бүрэлдэхүүн хэсэг {0} олдохгүй байна', '']
# 0.027158001009591117
# ['Unmarked Attendance for days', 'Өдрийн тэмдэглэлгүй ирц', '']
# 0.027258960121150935
# ['Vacancies cannot be lower than the current openings', 'Сул орон тоо нь одоо нээгдэж буй орон тооноос доогуур байж болохгүй', '']
# 0.027359919232710753
# ['{} is an invalid Attendance Status.', '{} ирцийн төлөв буруу байна.', '']
# 0.02746087834427057
# ['Printed On', 'Хэвлэсэн', '']
# 0.02756183745583039
# ['No employee found', 'Ажилтан олдсонгүй', '']
# 0.027662796567390208
# ['Please setup Employee Naming System in Human Resource > HR Settings', 'Хүний нөөц > Хүний нөөцийн тохиргоо хэсэгт Ажилтны нэрсийн системийг тохируулна уу', '']
# 0.027763755678950026
# ['Please setup numbering series for Attendance via Setup > Numbering Series', 'Тохируулах > Дугаарлах цувралаар ирцийг дугаарлах цувралыг тохируулна уу', '']
# 0.027864714790509844
# ['Current Odometer Value should be greater than Last Odometer Value {0}', 'Одоо байгаа зай хэмжигчний утга нь сүүлийн зай хэмжигчээс {0} их байх ёстой', '']
# 0.027965673902069662
# ['No additional expenses has been added', 'Нэмэлт зардал нэмээгүй', '']
# 0.02806663301362948
# ['{0} already exists for employee {1} and period {2}', '{1} ажилтан болон {2} хугацаанд {0} аль хэдийн байна', '']
# 0.028167592125189298
# ['Leaves Allocated', 'Навч хуваарилагдсан', '']
# 0.028268551236749116
# ['Leave Without Pay does not match with approved {} records', '"Төлбөргүй чөлөө" нь батлагдсан {} бүртгэлтэй таарахгүй байна', '']
# 0.028369510348308934
# ['Income Tax Slab not set in Salary Structure Assignment: {0}', 'Орлогын татварын хавтанг Цалингийн бүтцийн хуваарилалтад тохируулаагүй: {0}', '']
# 0.028470469459868752
# ['Income Tax Slab: {0} is disabled', 'Орлогын татварын хавтан: {0} идэвхгүй болсон', '']
# 0.02857142857142857
# ['Income Tax Slab must be effective on or before Payroll Period Start Date: {0}', 'Орлогын татварын хавтан нь Цалингийн хугацаа эхлэх өдөр эсвэл түүнээс өмнө хүчинтэй байх ёстой: {0}', '']
# 0.02867238768298839
# ['No leave record found for employee {0} on {1}', '{1}-д {0} ажилтны амралтын бүртгэл олдсонгүй', '']
# 0.028773346794548207
# ['Row {0}: {1} is required in the expenses table to book an expense claim.', '{0}-р мөр: Зардлын нэхэмжлэлийг захиалахын тулд зардлын хүснэгтэд {1} байх шаардлагатай.', '']
# 0.028874305906108025
# ['Set the default account for the {0} {1}', '{0} {1}-н өгөгдмөл бүртгэлийг тохируулах', '']
# 0.028975265017667843
# ['(Half Day)', '(Хагас өдөр)', '']
# 0.029076224129227664
# ['Income Tax Slab', 'Орлогын татварын хавтан', '']
# 0.029177183240787483
# ['Row #{0}: Cannot set amount or formula for Salary Component {1} with Variable Based On Taxable Salary', 'Мөр #{0}: Татвар ногдох цалинд суурилсан хувьсагчтай Цалингийн {1} бүрэлдэхүүн хэсгийн хэмжээ эсвэл томъёог тохируулах боломжгүй', '']
# 0.0292781423523473
# ['Repay From Salary can be selected only for term loans', 'Цалингаас эргэн төлөлтийг зөвхөн хугацаатай зээлээр сонгох боломжтой', '']
# 0.02937910146390712
# ['Salary Component Account', 'Цалингийн бүрэлдэхүүн хэсгийн данс', '']
# 0.029480060575466937
# ['Default Bank / Cash account will be automatically updated in Salary Journal Entry when this mode is selected.', 'Энэ горимыг сонгосон үед үндсэн банк / бэлэн мөнгөний данс Цалингийн журналын бичилтэд автоматаар шинэчлэгдэх болно.', '']
# 0.029581019687026755
# ['Result', 'Үр дүн', '']
# 0.029681978798586573
# ['Total Score', 'Нийт оноо', '']
# 0.02978293791014639
# ['Joining Date', 'Нэгдсэн огноо', '']
# 0.02988389702170621
# ['Publish on website', 'Вэбсайт дээр нийтлэх', '']
# 0.029984856133266027
# ['Application Status', 'Хэрэглээний статус', '']
# 0.030085815244825845
# ['IN', 'IN', '']
# 0.030186774356385664
# ['Remind Before', 'Өмнө нь сануул', '']
# 0.03028773346794548
# ['Reminded', 'Сануулсан', '']
# 0.0303886925795053
# ['Additional Salary', 'Нэмэлт цалин', '']
# 0.030489651691065118
# ['HR-ADS-.YY.-.MM.-', 'HR-ADS-.YY.-.MM.-', '']
# 0.030590610802624936
# ['Salary Component', 'Цалингийн бүрэлдэхүүн хэсэг', '']
# 0.030691569914184754
# ['Overwrite Salary Structure Amount', 'Цалингийн бүтцийн хэмжээг дарж бичнэ үү', '']
# 0.030792529025744572
# ['Deduct Full Tax on Selected Payroll Date', 'Сонгосон цалингийн огнооны татварыг бүрэн хасна', '']
# 0.03089348813730439
# ['Payroll Date', 'Цалингийн огноо', '']
# 0.03099444724886421
# ['Salary Component Type', 'Цалингийн бүрэлдэхүүн хэсгийн төрөл', '']
# 0.03109540636042403
# ['Appointment Letter', 'Томилох бичиг', '']
# 0.031196365471983848
# ['Appointment Date', 'Уулзалтын огноо', '']
# 0.031297324583543666
# ['Appointment Letter Template', 'Томилгооны захидлын загвар', '']
# 0.03139828369510348
# ['Closing Notes', 'Хаалтын тэмдэглэл', '']
# 0.0314992428066633
# ['Appointment Letter content', 'Томилгооны захидлын агуулга', '']
# 0.03160020191822312
# ['Appraisal', 'Үнэлгээ', '']
# 0.03170116102978294
# ['HR-APR-.YY.-.MM.', 'HR-APR-.YY.-.MM.', '']
# 0.03180212014134275
# ['For Employee Name', 'Ажилтны нэрийн хувьд', '']
# 0.031903079252902575
# ['Goals', 'Зорилго', '']
# 0.03200403836446239
# ['Total Score (Out of 5)', 'Нийт оноо (5-аас)', '']
# 0.03210499747602221
# ['Any other remarks, noteworthy effort that should go in the records.', 'Бусад тэмдэглэл, анхаарал татахуйц хүчин чармайлтыг бүртгэлд оруулах ёстой.', '']
# 0.03220595658758203
# ['Appraisal Goal', 'Үнэлгээний зорилго', '']
# 0.03230691569914185
# ['Key Responsibility Area', 'Хариуцлагын гол хэсэг', '']
# 0.03240787481070167
# ['Weightage (%)', 'Жин (%)', '']
# 0.03250883392226148
# ['Score (0-5)', 'Оноо (0-5)', '']
# 0.032609793033821305
# ['Score Earned', 'Авсан оноо', '']
# 0.03271075214538112
# ['Appraisal Template Title', 'Үнэлгээний загварын гарчиг', '']
# 0.03281171125694094
# ['Appraisal Template Goal', 'Үнэлгээний загварын зорилго', '']
# 0.032912670368500756
# ['KRA', 'KRA', '']
# 0.03301362948006058
# ['Key Performance Area', 'Гүйцэтгэлийн гол талбар', '']
# 0.03311458859162039
# ['HR-ATT-.YYYY.-', 'HR-ATT-.YYYY.-', '']
# 0.033215547703180213
# ['On Leave', 'Амралт дээр', '']
# 0.03331650681474003
# ['Work From Home', 'Гэрээсээ ажиллах', '']
# 0.03341746592629985
# ['Leave Application', 'Өргөдөл гаргах', '']
# 0.033518425037859664
# ['Attendance Date', 'Ирсэн огноо', '']
# 0.033619384149419486
# ['Attendance Request', 'Ирцийн хүсэлт', '']
# 0.0337203432609793
# ['Late Entry', 'Орох хоцрогдол', '']
# 0.03382130237253912
# ['Early Exit', 'Эрт гарах', '']
# 0.03392226148409894
# ['Half Day Date', 'Хагас өдрийн огноо', '']
# 0.03402322059565876
# ['On Duty', 'Үүрэгт', '']
# 0.03412417970721858
# ['Explanation', 'Тайлбар', '']
# 0.034225138818778394
# ['Compensatory Leave Request', 'Нөхөн олговрын чөлөө авах хүсэлт', '']
# 0.034326097930338216
# ['Leave Allocation', 'Хуваарилалтаас гарах', '']
# 0.03442705704189803
# ['Worked On Holiday', 'Амралтын өдрөөр ажилласан', '']
# 0.03452801615345785
# ['Work From Date', 'Огнооноос эхлэн ажиллах', '']
# 0.03462897526501767
# ['Work End Date', 'Ажил дуусах огноо', '']
# 0.03472993437657749
# ['Email Sent To', 'Имэйлийг илгээсэн', '']
# 0.0348308934881373
# ['Select Users', 'Хэрэглэгчийг сонгоно уу', '']
# 0.034931852599697125
# ['Send Emails At', 'Имэйл илгээх', '']
# 0.03503281171125694
# ['Reminder', 'Сануулга', '']
# 0.03513377082281676
# ['Daily Work Summary Group User', 'Өдөр тутмын ажлын хураангуй бүлгийн хэрэглэгч', '']
# 0.035234729934376575
# ['email', 'имэйл', '']
# 0.0353356890459364
# ['Department Approver', 'Хэлтсийн батламжлагч', '']
# 0.03543664815749621
# ['Approver', 'Зөвшөөрөгч', '']
# 0.03553760726905603
# ['Designation Skill', 'Зориулалтын ур чадвар', '']
# 0.03563856638061585
# ['Skill', 'Ур чадвар', '']
# 0.03573952549217567
# ['Leave Policy', 'Бодлого орхих', '']
# 0.035840484603735484
# ['Salary Details', 'Цалингийн дэлгэрэнгүй мэдээлэл', '']
# 0.035941443715295306
# ['HR-EAD-.YYYY.-', 'HR-EAD-.YYYY.-', '']
# 0.03604240282685512
# ['Claimed', 'Нэхэмжлэгдсэн', '']
# 0.03614336193841494
# ['Employee Attendance Tool', 'Ажилчдын ирцийн хэрэгсэл', '']
# 0.03624432104997476
# ['Unmarked Attendance', 'Тэмдэглэгдээгүй ирц', '']
# 0.03634528016153458
# ['Employees HTML', 'Ажилчдын HTML', '']
# 0.0364462392730944
# ['Marked Attendance', 'Тэмдэглэгдсэн ирц', '']
# 0.036547198384654214
# ['Marked Attendance HTML', 'Тэмдэглэгдсэн ирц HTML', '']
# 0.036648157496214036
# ['Employee Benefit Application', 'Ажилчдын тэтгэмжийн өргөдөл', '']
# 0.03674911660777385
# ['Max Benefits (Yearly)', 'Хамгийн их ашиг тус (жил бүр)', '']
# 0.03685007571933367
# ['Remaining Benefits (Yearly)', 'Үлдсэн ашиг тус (жил бүр)', '']
# 0.03695103483089349
# ['Payroll Period', 'Цалингийн хугацаа', '']
# 0.03705199394245331
# ['Dispensed Amount (Pro-rated)', 'Олгосон дүн (тооцоотой)', '']
# 0.03715295305401312
# ['Employee Benefit Application Detail', 'Ажилтны тэтгэмжийн өргөдлийн дэлгэрэнгүй', '']
# 0.037253912165572944
# ['Earning Component', 'Орлогын бүрэлдэхүүн хэсэг', '']
# 0.03735487127713276
# ['Pay Against Benefit Claim', 'Тэтгэмжийн нэхэмжлэлийн эсрэг төлөх', '']
# 0.03745583038869258
# ['Max Benefit Amount', 'Тэтгэмжийн дээд хэмжээ', '']
# 0.037556789500252395
# ['Employee Benefit Claim', 'Ажилтны тэтгэмжийн нэхэмжлэл', '']
# 0.03765774861181222
# ['Claim Date', 'Нэхэмжлэлийн огноо', '']
# 0.03775870772337203
# ['Claim Benefit For', 'Нэхэмжлэлийн тэтгэмж', '']
# 0.03785966683493185
# ['Max Amount Eligible', 'Боломжит дээд хэмжээ', '']
# 0.03796062594649167
# ['Expense Proof', 'Зардлын баталгаа', '']
# 0.03806158505805149
# ['Employee Boarding Activity', 'Ажилчдын дотуур байрны үйл ажиллагаа', '']
# 0.03816254416961131
# ['Activity Name', 'Үйл ажиллагааны нэр', '']
# 0.038263503281171125
# ['Required for Employee Creation', 'Ажилтан бий болгоход шаардлагатай', '']
# 0.03836446239273095
# ['Applicable in the case of Employee Onboarding', 'Ажилтныг ажилд авах тохиолдолд хамаарна', '']
# 0.03846542150429076
# ['Employee Checkin', 'Ажилтны бүртгэл', '']
# 0.03856638061585058
# ['Log Type', 'Бүртгэлийн төрөл', '']
# 0.0386673397274104
# ['OUT', 'ГАРСАН', '']
# 0.03876829883897022
# ['Location / Device ID', 'Байршил / Төхөөрөмжийн ID', '']
# 0.038869257950530034
# ['Skip Auto Attendance', 'Автомат ирцийг алгасах', '']
# 0.038970217062089856
# ['Shift Start', 'Shift Start', '']
# 0.03907117617364967
# ['Shift End', 'Шилжилтийн төгсгөл', '']
# 0.03917213528520949
# ['Shift Actual Start', 'Бодит эхлэлийг шилжүүлэх', '']
# 0.039273094396769306
# ['Shift Actual End', 'Бодит төгсгөлийг шилжүүлэх', '']
# 0.03937405350832913
# ['Default Salary Structure', 'Өгөгдмөл цалингийн бүтэц', '']
# 0.03947501261988894
# ['Employee Health Insurance', 'Ажилтны эрүүл мэндийн даатгал', '']
# 0.039575971731448764
# ['Health Insurance Name', 'Эрүүл мэндийн даатгалын нэр', '']
# 0.03967693084300858
# ['Employee Incentive', 'Ажилчдын урамшуулал', '']
# 0.0397778899545684
# ['Incentive Amount', 'Урамшууллын хэмжээ', '']
# 0.039878849066128215
# ['Employee Onboarding', 'Ажилтныг элсүүлэх', '']
# 0.039979808177688037
# ['Notify users by email', 'Хэрэглэгчдэд имэйлээр мэдэгдэх', '']
# 0.04008076728924786
# ['Employee Onboarding Template', 'Ажилтны ажилд авах загвар', '']
# 0.04018172640080767
# ['Employee Other Income', 'Ажилтны бусад орлого', '']
# 0.040282685512367494
# ['Employee Promotion', 'Ажилтны албан тушаал ахих', '']
# 0.04038364462392731
# ['Promotion Date', 'Сурталчилгааны огноо', '']
# 0.04048460373548713
# ['Employee Promotion Details', 'Ажилтны албан тушаал ахих тухай мэдээлэл', '']
# 0.040585562847046945
# ['Employee Property History', 'Ажилчдын өмчийн түүх', '']
# 0.04068652195860677
# ['Employee Separation', 'Ажилтныг тусгаарлах', '']
# 0.04078748107016658
# ['Employee Separation Template', 'Ажилтныг тусгаарлах загвар', '']
# 0.0408884401817264
# ['Exit Interview Summary', 'Ярилцлагын хураангуй', '']
# 0.04098939929328622
# ['Employee Skill', 'Ажилчдын ур чадвар', '']
# 0.04109035840484604
# ['Proficiency', 'Ур чадвар', '']
# 0.041191317516405854
# ['Evaluation Date', 'Үнэлгээний огноо', '']
# 0.041292276627965675
# ['Employee Skill Map', 'Ажилчдын ур чадварын зураг', '']
# 0.04139323573952549
# ['Employee Skills', 'Ажилчдын ур чадвар', '']
# 0.04149419485108531
# ['Trainings', 'Сургалтууд', '']
# 0.041595153962645126
# ['Employee Tax Exemption Category', 'Ажилтны татвараас чөлөөлөх ангилал', '']
# 0.04169611307420495
# ['Max Exemption Amount', 'Чөлөөлөлтийн дээд хэмжээ', '']
# 0.04179707218576476
# ['Employee Tax Exemption Declaration', 'Ажилтны татвараас чөлөөлөх тухай мэдэгдэл', '']
# 0.041898031297324584
# ['Declarations', 'Тунхаглал', '']
# 0.0419989904088844
# ['Total Declared Amount', 'Нийт мэдүүлсэн дүн', '']
# 0.04209994952044422
# ['Total Exemption Amount', 'Чөлөөлөлтийн нийт дүн', '']
# 0.04220090863200404
# ['Employee Tax Exemption Declaration Category', 'Ажилтны татвараас чөлөөлөх тухай мэдүүлгийн ангилал', '']
# 0.042301867743563856
# ['Exemption Sub Category', 'Чөлөөлөлтийн дэд ангилал', '']
# 0.04240282685512368
# ['Exemption Category', 'Чөлөөлөлтийн ангилал', '']
# 0.04250378596668349
# ['Maximum Exempted Amount', 'Чөлөөлөгдсөн дээд хэмжээ', '']
# 0.042604745078243314
# ['Declared Amount', 'Зарласан дүн', '']
# 0.04270570418980313
# ['Employee Tax Exemption Proof Submission', 'Ажилтны татвараас чөлөөлөгдсөн тухай нотлох баримтыг ирүүлэх', '']
# 0.04280666330136295
# ['Submission Date', 'Оруулсан огноо', '']
# 0.042907622412922765
# ['Tax Exemption Proofs', 'Татвараас чөлөөлөх тухай баримтууд', '']
# 0.043008581524482586
# ['Total Actual Amount', 'Нийт бодит дүн', '']
# 0.0431095406360424
# ['Employee Tax Exemption Proof Submission Detail', 'Ажилтны татвараас чөлөөлөгдсөнийг нотлох баримтын дэлгэрэнгүй мэдээлэл', '']
# 0.04321049974760222
# ['Maximum Exemption Amount', 'Чөлөөлөлтийн дээд хэмжээ', '']
# 0.04331145885916204
# ['Type of Proof', 'Нотлох баримтын төрөл', '']
# 0.04341241797072186
# ['Actual Amount', 'Бодит дүн', '']
# 0.04351337708228167
# ['Employee Tax Exemption Sub Category', 'Ажилтны татвараас чөлөөлөх дэд ангилал', '']
# 0.043614336193841495
# ['Tax Exemption Category', 'Татвараас чөлөөлөх ангилал', '']
# 0.04371529530540131
# ['Employee Training', 'Ажилтны сургалт', '']
# 0.04381625441696113
# ['Training Date', 'Сургалтын огноо', '']
# 0.043917213528520946
# ['Employee Transfer', 'Ажилтныг шилжүүлэх', '']
# 0.04401817264008077
# ['Transfer Date', 'Шилжүүлгийн огноо', '']
# 0.04411913175164059
# ['Employee Transfer Details', 'Ажилтныг шилжүүлэх дэлгэрэнгүй мэдээлэл', '']
# 0.044220090863200404
# ['Employee Transfer Detail', 'Ажилтныг шилжүүлэх дэлгэрэнгүй мэдээлэл', '']
# 0.044321049974760225
# ['Re-allocate Leaves', 'Навчийг дахин хуваарилах', '']
# 0.04442200908632004
# ['Create New Employee Id', 'Шинэ ажилтны ID үүсгэх', '']
# 0.04452296819787986
# ['New Employee ID', 'Шинэ ажилтны үнэмлэх', '']
# 0.044623927309439676
# ['HR-EXP-.YYYY.-', 'HR-EXP-.YYYY.-', '']
# 0.0447248864209995
# ['Expense Taxes and Charges', 'Зардлын татвар, хураамж', '']
# 0.04482584553255931
# ['Total Sanctioned Amount', 'Шийтгэлийн нийт дүн', '']
# 0.044926804644119134
# ['Total Advance Amount', 'Урьдчилгаа нийт дүн', '']
# 0.04502776375567895
# ['Total Claimed Amount', 'Нэхэмжлэгдсэн нийт дүн', '']
# 0.04512872286723877
# ['Total Amount Reimbursed', 'Нөхөн олгосон нийт дүн', '']
# 0.045229681978798585
# ['Vehicle Log', 'Тээврийн хэрэгслийн бүртгэл', '']
# 0.045330641090358406
# ['Employees Email Id', 'Ажилчдын цахим шуудангийн дугаар', '']
# 0.04543160020191822
# ['More Details', 'Илүү дэлгэрэнгүй мэдээллийг', '']
# 0.04553255931347804
# ['Expense Claim Account', 'Зардлын нэхэмжлэлийн данс', '']
# 0.04563351842503786
# ['Expense Claim Advance', 'Зардлын нэхэмжлэлийн урьдчилгаа', '']
# 0.04573447753659768
# ['Expense Claim Detail', 'Зардлын нэхэмжлэлийн дэлгэрэнгүй', '']
# 0.04583543664815749
# ['Expense Date', 'Зардлын огноо', '']
# 0.045936395759717315
# ['Expense Claim Type', 'Зардлын нэхэмжлэлийн төрөл', '']
# 0.04603735487127713
# ['HR Settings', 'Хүний нөөцийн тохиргоо', '']
# 0.04613831398283695
# ['Employee Settings', 'Ажилтны тохиргоо', '']
# 0.04623927309439677
# ['Expense Approver Mandatory In Expense Claim', 'Зардлын батламжлагч Зардлын нэхэмжлэлд заавал байх ёстой', '']
# 0.04634023220595659
# ['Payroll Settings', 'Цалингийн тохиргоо', '']
# 0.04644119131751641
# ['Leave', 'Орхих', '']
# 0.04654215042907622
# ['Max working hours against Timesheet', 'Цагийн хүснэгттэй харьцуулахад хамгийн их ажлын цаг', '']
# 0.046643109540636045
# ['Include holidays in Total no. of Working Days', 'Амралтын өдрүүдийг нийт тоонд оруулна. Ажлын өдрүүдийн тухай', '']
# 0.04674406865219586
# ['If checked, Total no. of Working Days will include holidays, and this will reduce the value of Salary Per Day', 'Хэрэв шалгасан бол Нийт дугаар. Ажлын өдрүүдэд амралтын өдрүүд багтах бөгөөд энэ нь өдрийн цалингийн үнэ цэнийг бууруулна', '']
# 0.04684502776375568
# ['If checked, hides and disables Rounded Total field in Salary Slips', 'Хэрэв чагтсан бол Цалингийн хуудасны дугуйрсан нийт талбарыг нууж, идэвхгүй болгоно', '']
# 0.046945986875315496
# ['The fraction of daily wages to be paid for half-day attendance', 'Хагас өдрийн ирцэд төлөх өдрийн цалингийн хэсэг', '']
# 0.04704694598687532
# ['Email Salary Slip to Employee', 'Цалингийн хуудсыг ажилтан руу имэйлээр илгээнэ үү', '']
# 0.04714790509843513
# ['Emails salary slip to employee based on preferred email selected in Employee', 'Ажилтны сонгосон имэйлд үндэслэн цалингийн хуудсыг ажилчид руу илгээнэ', '']
# 0.047248864209994954
# ['Encrypt Salary Slips in Emails', 'Цалингийн хуудсыг цахим шуудангаар шифрлэх', '']
# 0.04734982332155477
# ['The salary slip emailed to the employee will be password protected, the password will be generated based on the password policy.', 'Ажилтан руу илгээсэн цалингийн хуудас нь нууц үгээр хамгаалагдсан байх бөгөөд нууц үгийн бодлогод үндэслэн нууц үг үүсгэгдэнэ.', '']
# 0.04745078243311459
# ['Password Policy', 'Нууц үгийн бодлого', '']
# 0.047551741544674404
# ['<b>Example:</b> SAL-{first_name}-{date_of_birth.year} <br>This will generate a password like SAL-Jane-1972', '<b>Жишээ нь:</b> SAL-{first_name}-{date_of_birth.year} <br>Энэ нь SAL-Jane-1972 шиг нууц үг үүсгэх болно', '']
# 0.047652700656234226
# ['Leave Approval Notification Template', 'Зөвшөөрлийн мэдэгдлийн загварыг үлдээнэ үү', '']
# 0.04775365976779404
# ['Leave Status Notification Template', 'Статусын мэдэгдлийн загварыг орхи', '']
# 0.04785461887935386
# ['Role Allowed to Create Backdated Leave Application', 'Хугацаа хоцрогдсон чөлөөний програм үүсгэхийг зөвшөөрсөн үүрэг', '']
# 0.04795557799091368
# ['Leave Approver Mandatory In Leave Application', 'Өргөдөл гаргахдаа зөвшөөрөл авагчийг заавал үлдээх хэрэгтэй', '']
# 0.0480565371024735
# ['Show Leaves Of All Department Members In Calendar', 'Календарт тэнхимийн бүх гишүүдийн навчийг харуулах', '']
# 0.04815749621403332
# ['Auto Leave Encashment', 'Автоматаар гарах орлого', '']
# 0.048258455325593134
# ['Hiring Settings', 'Ажилд авах тохиргоо', '']
# 0.048359414437152956
# ['Check Vacancies On Job Offer Creation', 'Ажлын санал бий болгох талаар сул орон тоог шалгана уу', '']
# 0.04846037354871277
# ['Identification Document Type', 'Тодорхойлох баримт бичгийн төрөл', '']
# 0.04856133266027259
# ['Effective from', '-аас хүчинтэй', '']
# 0.04866229177183241
# ['Allow Tax Exemption', 'Татвараас чөлөөлөхийг зөвшөөрөх', '']
# 0.04876325088339223
# ['If enabled, Tax Exemption Declaration will be considered for income tax calculation.', 'Хэрэв идэвхжүүлсэн бол орлогын албан татварыг тооцохдоо Татвараас чөлөөлөх тухай мэдэгдлийг авч үзнэ.', '']
# 0.04886420999495204
# ['Standard Tax Exemption Amount', 'Татвараас чөлөөлөх стандарт хэмжээ', '']
# 0.048965169106511865
# ['Taxable Salary Slabs', 'Татвар ногдох цалингийн хавтан', '']
# 0.04906612821807168
# ['Taxes and Charges on Income Tax', 'Орлогын албан татвар, хураамж', '']
# 0.0491670873296315
# ['Other Taxes and Charges', 'Бусад татвар, хураамж', '']
# 0.049268046441191315
# ['Income Tax Slab Other Charges', 'Орлогын татварын хавтан Бусад хураамж', '']
# 0.04936900555275114
# ['Min Taxable Income', 'Татвар ногдох хамгийн бага орлого', '']
# 0.04946996466431095
# ['Max Taxable Income', 'Хамгийн их татвар ногдуулах орлого', '']
# 0.04957092377587077
# ['Applicant for a Job', 'Ажилд орох өргөдөл гаргагч', '']
# 0.04967188288743059
# ['Job Opening', 'Нээлттэй ажлын байр', '']
# 0.04977284199899041
# ['Cover Letter', 'Cover Letter', '']
# 0.049873801110550224
# ['Resume Attachment', 'Хавсралтыг үргэлжлүүлэх', '']
# 0.049974760222110046
# ['Job Applicant Source', 'Ажил горилогчийн эх сурвалж', '']
# 0.05007571933366986
# ['Applicant Email Address', 'Өргөдөл гаргагчийн имэйл хаяг', '']
# 0.05017667844522968
# ['Awaiting Response', 'Хариулт хүлээж байна', '']
# 0.0502776375567895
# ['Job Offer Terms', 'Ажлын санал болгох нөхцөл', '']
# 0.05037859666834932
# ['Select Terms and Conditions', 'Нөхцөлүүдийг сонгоно уу', '']
# 0.05047955577990914
# ['Job Offer Term', 'Ажлын санал болгох хугацаа', '']
# 0.050580514891468954
# ['Offer Term', 'Санал болгох хугацаа', '']
# 0.050681474003028776
# ['Value / Description', 'Үнэ цэнэ / Тайлбар', '']
# 0.05078243311458859
# ['Description of a Job Opening', 'Нээлтийн ажлын байрны тодорхойлолт', '']
# 0.05088339222614841
# ['Staffing Plan', 'Боловсон хүчний төлөвлөгөө', '']
# 0.05098435133770823
# ['Planned number of Positions', 'Төлөвлөсөн албан тушаалын тоо', '']
# 0.05108531044926805
# ...
# 0.06501766784452297
# ['Time after the end of shift during which check-out is considered for attendance.', 'Ээлж дууссанаас хойшхи цаг, энэ хугацаанд гарахыг ирцэнд тооцно.', '']
# 0.06511862695608278
# ['Working Hours Threshold for Half Day', 'Хагас өдрийн ажлын цагийн босго', '']
# 0.06521958606764261
# ['Working hours below which Half Day is marked. (Zero to disable)', 'Хагас өдрийг тэмдэглэсэн ажлын цаг. (Идэвхгүй болгохын тулд тэг)', '']
# 0.06532054517920242
# ['Working Hours Threshold for Absent', 'Эзгүй хүмүүсийн ажлын цагийн босго', '']
# 0.06542150429076224
# ['Working hours below which Absent is marked. (Zero to disable)', 'Эзгүй гэж тэмдэглэсэн ажлын цаг. (Идэвхгүй болгохын тулд тэг)', '']
# 0.06552246340232205
# ['Process Attendance After', 'Дараа нь ирцийг боловсруулах', '']
# 0.06562342251388188
# ['Attendance will be marked automatically only after this date.', 'Зөвхөн энэ өдрөөс хойш ирцийг автоматаар тэмдэглэнэ.', '']
# 0.0657243816254417
# ['Last Sync of Checkin', 'Бүртгэлийн сүүлчийн синк', '']
# 0.06582534073700151
# ["Last Known Successful Sync of Employee Checkin. Reset this only if you are sure that all Logs are synced from all the locations. Please don't modify this if you are unsure.", 'Ажилтны бүртгэлийн хамгийн сүүлд мэдэгдэж байгаа амжилттай синк. Хэрэв та бүх бүртгэлийг бүх байршлаас синк хийсэн гэдэгт итгэлтэй байгаа бол үүнийг дахин тохируулна уу. Хэрэв та эргэлзэж байвал үүнийг бүү өөрчил.', '']
# 0.06592629984856133
# ['Grace Period Settings For Auto Attendance', 'Автомат ирцэд зориулсан хөнгөлөлтийн хугацааны тохиргоо', '']
# 0.06602725896012115
# ['Enable Entry Grace Period', 'Нэвтрэх хөнгөлөлтийн хугацааг идэвхжүүлнэ үү', '']
# 0.06612821807168097
# ['Late Entry Grace Period', 'Хожуу нэвтрэх хөнгөлөлтийн хугацаа', '']
# 0.06622917718324078
# ['The time after the shift start time when check-in is considered as late (in minutes).', 'Бүртгэлийг хоцрогдсонд тооцдог ээлж эхлэхээс хойшхи цаг (минутаар).', '']
# 0.06633013629480061
# ['Enable Exit Grace Period', 'Гарах хөнгөлөлтийн хугацааг идэвхжүүлэх', '']
# 0.06643109540636043
# ['Early Exit Grace Period', 'Эрт гарах хөнгөлөлтийн хугацаа', '']
# 0.06653205451792024
# ['The time before the shift end time when check-out is considered as early (in minutes).', 'Шалгалт дуусахаас өмнөх цагийг (минутаар) эрт тооцно.', '']
# 0.06663301362948006
# ['Skill Name', 'Ур чадварын нэр', '']
# 0.06673397274103988
# ['Staffing Plan Detail', 'Боловсон хүчний төлөвлөгөөний дэлгэрэнгүй', '']
# 0.0668349318525997
# ['Total Estimated Budget', 'Нийт тооцоолсон төсөв', '']
# 0.06693589096415951
# ['Vacancies', 'Сул орон тоо', '']
# 0.06703685007571933
# ['Estimated Cost Per Position', 'Нэг албан тушаалд ногдох тооцоолсон зардал', '']
# 0.06713780918727916
# ['Total Estimated Cost', 'Нийт тооцоолсон зардал', '']
# 0.06723876829883897
# ['Current Count', 'Одоогийн тоо', '']
# 0.06733972741039879
# ['Current Openings', 'Одоогийн нээлтүүд', '']
# 0.0674406865219586
# ['Number Of Positions', 'Албан тушаалын тоо', '']
# 0.06754164563351843
# ['Taxable Salary Slab', 'Татвар ногдох цалингийн хавтан', '']
# 0.06764260474507824
# ['From Amount', 'Тоо хэмжээнээс', '']
# 0.06774356385663806
# ['To Amount', 'Хэмжээнд', '']
# 0.06784452296819787
# ['Percent Deduction', 'хувийн суутгал', '']
# 0.0679454820797577
# ['Training Program', 'Сургалтын хөтөлбөр', '']
# 0.06804644119131752
# ['Event Status', 'Үйл явдлын төлөв', '']
# 0.06814740030287733
# ['Has Certificate', 'Сертификаттай', '']
# 0.06824835941443716
# ['Seminar', 'Семинар', '']
# 0.06834931852599697
# ['Theory', 'Онол', '']
# 0.06845027763755679
# ['Workshop', 'Семинар', '']
# 0.0685512367491166
# ['Conference', 'Бага хурал', '']
# 0.06865219586067643
# ['Exam', 'Шалгалт', '']
# 0.06875315497223625
# ['Internet', 'Интернет', '']
# 0.06885411408379606
# ['Self-Study', 'Бие даан суралцах', '']
# 0.06895507319535588
# ['Advance', 'Урьдчилгаа', '']
# 0.0690560323069157
# ['Trainer Name', 'Дасгалжуулагчийн нэр', '']
# 0.06915699141847552
# ['Trainer Email', 'Дасгалжуулагчийн имэйл', '']
# 0.06925795053003533
# ['Attendees', 'Оролцогчид', '']
# 0.06935890964159515
# ['Employee Emails', 'Ажилчдын имэйл', '']
# 0.06945986875315498
# ['Training Event Employee', 'Сургалтын арга хэмжээний ажилтан', '']
# 0.06956082786471479
# ['Invited', 'Урьсан', '']
# 0.0696617869762746
# ['Feedback Submitted', 'Санал хүсэлт илгээсэн', '']
# 0.06976274608783442
# ['Training Result Employee', 'Сургалтын үр дүнгийн ажилтан', '']
# 0.06986370519939425
# ['Travel Itinerary', 'Аялалын маршрут', '']
# 0.06996466431095406
# ['Travel From', 'Аялал', '']
# 0.07006562342251388
# ['Travel To', 'Аялах', '']
# 0.07016658253407371
# ['Mode of Travel', 'Аяллын горим', '']
# 0.07026754164563352
# ['Flight', 'Нислэг', '']
# 0.07036850075719334
# ['Train', 'Галт тэрэг', '']
# 0.07046945986875315
# ['Taxi', 'Такси', '']
# 0.07057041898031298
# ['Rented Car', 'Түрээсийн машин', '']
# 0.0706713780918728
# ['Meal Preference', 'Хоолны давуу тал', '']
# 0.07077233720343261
# ['Vegetarian', 'Цагаан хоолтон', '']
# 0.07087329631499242
# ['Non-Vegetarian', 'Цагаан хоолтон биш', '']
# 0.07097425542655225
# ['Gluten Free', 'Цавуулаггүй', '']
# 0.07107521453811207
# ['Non Diary', 'Сүүний бус', '']
# 0.07117617364967188
# ['Travel Advance Required', 'Аялал жуулчлалын урьдчилгаа шаардлагатай', '']
# 0.0712771327612317
# ['Departure Datetime', 'Явах огноо', '']
# 0.07137809187279152
# ['Arrival Datetime', 'Ирэх огноо', '']
# 0.07147905098435134
# ['Lodging Required', 'Орон байр шаардлагатай', '']
# 0.07158001009591115
# ['Preferred Area for Lodging', 'Зочид буудаллахад тохиромжтой бүс', '']
# 0.07168096920747097
# ['Check-in Date', 'Бүртгүүлэх огноо', '']
# 0.0717819283190308
# ['Check-out Date', 'Гарах огноо', '']
# 0.07188288743059061
# ['Travel Request', 'Аялал жуулчлалын хүсэлт', '']
# 0.07198384654215043
# ['Travel Type', 'Аялал жуулчлалын төрөл', '']
# 0.07208480565371024
# ['Domestic', 'Дотоодын', '']
# 0.07218576476527007
# ['International', 'Олон улсын', '']
# 0.07228672387682988
# ['Travel Funding', 'Аялал жуулчлалын санхүүжилт', '']
# 0.0723876829883897
# ['Require Full Funding', 'Бүрэн санхүүжилт шаардах', '']
# 0.07248864209994953
# ['Fully Sponsored', 'Бүрэн ивээн тэтгэсэн', '']
# 0.07258960121150934
# ['Partially Sponsored, Require Partial Funding', 'Хэсэгчилсэн ивээн тэтгэсэн, хэсэгчилсэн санхүүжилт шаардлагатай', '']
# 0.07269056032306916
# ['Copy of Invitation/Announcement', 'Урилга / Зарын хуулбар', '']
# 0.07279151943462897
# ['Details of Sponsor (Name, Location)', 'Ивээн тэтгэгчийн дэлгэрэнгүй мэдээлэл (нэр, байршил)', '']
# 0.0728924785461888
# ['Identification Document Number', 'Иргэний үнэмлэхний дугаар', '']
# 0.07299343765774861
# ['Any other details', 'Бусад дэлгэрэнгүй мэдээлэл', '']
# 0.07309439676930843
# ['Costing Details', 'Зардлын дэлгэрэнгүй мэдээлэл', '']
# 0.07319535588086824
# ['Event Details', 'Үйл явдлын дэлгэрэнгүй мэдээлэл', '']
# 0.07329631499242807
# ['Name of Organizer', 'Зохион байгуулагчийн нэр', '']
# 0.07339727410398789
# ['Address of Organizer', 'Зохион байгуулагчийн хаяг', '']
# 0.0734982332155477
# ['Travel Request Costing', 'Аялал жуулчлалын хүсэлтийн зардал', '']
# 0.07359919232710752
# ['Expense Type', 'Зардлын төрөл', '']
# 0.07370015143866734
# ['Sponsored Amount', 'Ивээн тэтгэсэн дүн', '']
# 0.07380111055022716
# ['Funded Amount', 'Санхүүжүүлсэн дүн', '']
# 0.07390206966178697
# ['Upload Attendance', 'Ирцийг байршуулах', '']
# 0.07400302877334679
# ['Attendance From Date', 'Огнооноос ирц', '']
# 0.07410398788490662
# ['Attendance To Date', 'Өнөөдрийг хүртэл ирц', '']
# 0.07420494699646643
# ['Get Template', 'Загвар авах', '']
# 0.07430590610802625
# ['Import Attendance', 'Импортын ирц', '']
# 0.07440686521958607
# ['Upload HTML', 'HTML байршуулах', '']
# 0.07450782433114589
# ['HR-VLOG-.YYYY.-', 'HR-VLOG-.YYYY.-', '']
# 0.0746087834427057
# ['Odometer Reading', 'Одометрийн уншилт', '']
# 0.07470974255426552
# ['Current Odometer value ', 'Одоогийн Odometer утга', '']
# 0.07481070166582535
# ['Refuelling Details', 'Шатахуун цэнэглэх дэлгэрэнгүй мэдээлэл', '']
# 0.07491166077738516
# ['Invoice Ref', 'Нэхэмжлэхийн лавлагаа', '']
# 0.07501261988894498
# ['Service Details', 'Үйлчилгээний дэлгэрэнгүй мэдээлэл', '']
# 0.07511357900050479
# ['Vehicle Service', 'Тээврийн хэрэгслийн үйлчилгээ', '']
# 0.07521453811206462
# ['Service Item', 'Үйлчилгээний зүйл', '']
# 0.07531549722362443
# ['Brake Oil', 'Тоормосны тос', '']
# 0.07541645633518425
# ['Brake Pad', 'Тоормосны дэвсгэр', '']
# 0.07551741544674406
# ['Clutch Plate', 'Авцуулах хавтан', '']
# 0.07561837455830389
# ['Engine Oil', 'Хөдөлгүүрийн тос', '']
# 0.0757193336698637
# ['Oil Change', 'Газрын тосны өөрчлөлт', '']
# 0.07582029278142352
# ['Inspection', 'Хяналт шалгалт', '']
# 0.07592125189298334
# ['Mileage', 'Миль', '']
# 0.07602221100454316
# ['Salary Slip Loan', 'Цалингийн хуудасны зээл', '']
# 0.07612317011610298
# ['Loan Repayment Entry', 'Зээлийн эргэн төлөлтийн бүртгэл', '']
# 0.07622412922766279
# ['May', 'Тавдугаар сар', '']
# 0.07632508833922262
# ['June', 'Зургадугаар сар', '']
# 0.07642604745078244
# ['July', 'долдугаар сар', '']
# 0.07652700656234225
# ['Bank Remittance', 'Банкны мөнгөн гуйвуулга', '']
# 0.07662796567390207
# ['Daily Work Summary Replies', 'Өдөр тутмын ажлын хураангуй хариултууд', '']
# 0.0767289247854619
# ['Employee Advance Summary', 'Ажилчдын урьдчилгаа хураангуй', '']
# 0.07682988389702171
# ['Employees working on a holiday', 'Амралтын өдрөөр ажилладаг ажилчид', '']
# 0.07693084300858152
# ['Monthly Attendance Sheet', 'Сар бүрийн ирцийн хуудас', '']
# 0.07703180212014134
# ['Salary Register', 'Цалингийн бүртгэл', '']
# 0.07713276123170117
# ['Unpaid Expense Claim', 'Төлөгдөөгүй зардлын нэхэмжлэл', '']
# 0.07723372034326098
# ['Payment Account is mandatory', 'Төлбөрийн данс заавал байх ёстой', '']
# 0.0773346794548208
# ['If checked, the full amount will be deducted from taxable income before calculating income tax without any declaration or proof submission.', 'Шалгасан тохиолдолд орлогын албан татварыг тооцохоос өмнө ямар нэгэн мэдүүлэг, нотлох баримтгүйгээр татвар ногдох орлогоос бүрэн хэмжээгээр хасна.', '']
# 0.07743563856638061
# ['In Time', 'Цагтаа', '']
# 0.07753659767794044
# ['Out Time', 'Гарах цаг', '']
# 0.07763755678950025
# ['Is Recurring', 'Давтагдаж байна', '']
# 0.07773851590106007
# ['HRA Exemption', 'HRA чөлөөлөх', '']
# 0.07783947501261988
# ['Monthly House Rent', 'Сарын түрээс', '']
# 0.07794043412417971
# ['Rented in Metro City', 'Metro City-д түрээслүүлнэ', '']
# 0.07804139323573953
# ['HRA as per Salary Structure', 'Цалингийн бүтцийн дагуу HRA', '']
# 0.07814235234729934
# ['Annual HRA Exemption', 'Жил бүрийн HRA чөлөөлөлт', '']
# 0.07824331145885917
# ['Monthly HRA Exemption', 'Сар бүрийн HRA чөлөөлөлт', '']
# 0.07834427057041898
# ['House Rent Payment Amount', 'Байшингийн түрээсийн төлбөрийн хэмжээ', '']
# 0.0784452296819788
# ['Rented From Date', 'огнооноос хойш түрээсэлсэн', '']
# 0.07854618879353861
# ['Rented To Date', 'Өнөөдрийг хүртэл түрээсэлсэн', '']
# 0.07864714790509844
# ['Monthly Eligible Amount', 'Сарын зөвшөөрөгдсөн хэмжээ', '']
# 0.07874810701665826
# ['Total Eligible HRA Exemption', 'Нийт эрх бүхий HRA чөлөөлөлт', '']
# 0.07884906612821807
# ['Validating Employee Attendance...', 'Ажилчдын ирцийг баталгаажуулж байна...', '']
# 0.07895002523977789
# ['Submitting Salary Slips and creating Journal Entry...', 'Цалингийн хуудас илгээж, журналын бичилт үүсгэж байна...', '']
# 0.07905098435133771
# ['Calculate Payroll Working Days Based On', 'Цалингийн ажлын өдрүүдийг үндэслэн тооцоол', '']
# 0.07915194346289753
# ['Consider Unmarked Attendance As', 'Тэмдэглэгдээгүй ирцийг гэж үзнэ үү', '']
# 0.07925290257445734
# ['Fraction of Daily Salary for Half Day', 'Хагас өдрийн цалингийн нэг хэсэг', '']
# 0.07935386168601716
# ['Component Type', 'Бүрэлдэхүүн хэсгийн төрөл', '']
# 0.07945482079757699
# ['Provident Fund', 'Провидент сан', '']
# 0.0795557799091368
# ['Additional Provident Fund', 'Нэмэлт тусламжийн сан', '']
# 0.07965673902069662
# ['Provident Fund Loan', 'Провидент сангийн зээл', '']
# 0.07975769813225643
# ['Professional Tax', 'Мэргэжлийн татвар', '']
# 0.07985865724381626
# ['Is Income Tax Component', 'Орлогын татварын бүрэлдэхүүн хэсэг юм', '']
# 0.07995961635537607
# ['Component properties and references ', 'Бүрэлдэхүүн хэсгүүдийн шинж чанарууд ба лавлагаа', '']
# 0.08006057546693589
# ['Additional Salary ', 'Нэмэлт цалин', '']
# 0.08016153457849572
# ['Unmarked days', 'Тэмдэглэгдээгүй өдрүүд', '']
# 0.08026249369005553
# ['Absent Days', 'Эзгүй өдрүүд', '']
# 0.08036345280161535
# ['Conditions and Formula variable and example', 'Нөхцөл ба томъёоны хувьсагч ба жишээ', '']
# 0.08046441191317516
# ['Income Tax Deductions', 'Орлогын албан татварын хөнгөлөлт', '']
# 0.08056537102473499
# ['Income Tax Component', 'Орлогын татварын бүрэлдэхүүн хэсэг', '']
# 0.0806663301362948
# ['Income Tax Amount', 'Орлогын татварын хэмжээ', '']
# 0.08076728924785462
# ['Unmarked Days', 'Тэмдэглэгдээгүй өдрүүд', '']
# 0.08086824835941443
# ['Jan', '1-р сар', '']
# 0.08096920747097426
# ['Feb', 'Хоёрдугаар сар', '']
# 0.08107016658253408
# ['Mar', '3-р сар', '']
# 0.08117112569409389
# ['Apr', '4-р сар', '']
# 0.0812720848056537
# ['Aug', 'Наймдугаар сар', '']
# 0.08137304391721353
# ['Sep', '9-р сар', '']
# 0.08147400302877335
# ['Oct', 'Аравдугаар сар', '']
# 0.08157496214033316
# ['Nov', '11-р сар', '']
# 0.08167592125189298
# ['Dec', '12-р сар', '']
# 0.0817768803634528
# ['Summarized View', 'Дүгнэж харах', '']
# 0.08187783947501262
# ['Professional Tax Deductions', 'Мэргэжлийн татварын хөнгөлөлт', '']
# 0.08197879858657244
# ['Provident Fund Deductions', 'Сангийн суутгал', '']
# 0.08207975769813225
# ['Recruitment Analytics', 'Ажилд авах аналитик', '']
# 0.08218071680969208
# ['Applicant name', 'Өргөдөл гаргагчийн нэр', '']
# 0.08228167592125189
# ['Job Offer status', 'Ажлын саналын статус', '']
# 0.08238263503281171
# ['On Date', 'Огноо', '']
# 0.08248359414437154
# ['Salary Payments Based On Payment Mode', 'Төлбөрийн горимд суурилсан цалингийн төлбөр', '']
# 0.08258455325593135
# ['Salary Payments via ECS', 'Цалингийн төлбөрийг ECS-ээр хийдэг', '']
# 0.08268551236749117
# ['Account No', 'Дансны дугаар', '']
# 0.08278647147905098
# ['IFSC', 'IFSC', '']
# 0.08288743059061081
# ['MICR', 'MICR', '']
# 0.08298838970217062
# ['PF Account', 'PF данс', '']
# 0.08308934881373044
# ['PF Amount', 'PF-ийн хэмжээ', '']
# 0.08319030792529025
# ['Additional PF', 'Нэмэлт PF', '']
# 0.08329126703685008
# ['PF Loan', 'PF зээл', '']
# 0.0833922261484099
# ['Duplicate Entry', 'Давхардсан оруулга', '']
# 0.08349318525996971
# ['Please select Employee first.', 'Эхлээд Ажилтнаа сонгоно уу.', '']
# 0.08359414437152952
# ['To Date should be greater than From Date', 'To Date нь From Date-аас их байх ёстой', '']
# 0.08369510348308935
# ['Job Offer: {0} is already for Job Applicant: {1}', 'Ажлын санал: {0} ажил горилогчид аль хэдийн байна: {1}', '']
# 0.08379606259464917
# ["Only Shift Request with status 'Approved' and 'Rejected' can be submitted", 'Зөвхөн "Зөвшөөрсөн" болон "Татгалзсан" статустай ээлжийн хүсэлтийг гаргаж болно', '']
# 0.08389702170620898
# ['Shift Assignment: {0} created for Employee: {1}', 'Ээлжийн даалгавар: {0} ажилтанд зориулан үүсгэсэн: {1}', '']
# 0.0839979808177688
# ['You can not request for your Default Shift: {0}', 'Та өгөгдмөл шилжилтийн хүсэлт гаргах боломжгүй: {0}', '']
# 0.08409893992932863
# ['Only Approvers can Approve this Request.', 'Зөвхөн Зөвшөөрөгчид энэ хүсэлтийг зөвшөөрөх боломжтой.', '']
# 0.08419989904088844
# ['Please set Payroll based on in Payroll settings', 'Цалингийн тохиргоонд үндэслэн Цалингийн хэмжээг тохируулна уу', '']
# 0.08430085815244825
# ['Additional Salary: {0} already exist for Salary Component: {1} for period {2} and {3}', 'Нэмэлт цалин: Цалингийн бүрэлдэхүүн хэсэгт {0} аль хэдийн байгаа: {2} ба {3} хугацаанд {1}', '']
# 0.08440181726400808
# ["Payroll date can not be less than employee's joining date.", 'Цалингийн огноо нь ажилтны ажилд орсон өдрөөс бага байж болохгүй.', '']
# 0.0845027763755679
# ["From date can not be less than employee's joining date.", 'Энэ өдрөөс эхлэн ажилтны нэгдсэн өдрөөс бага байж болохгүй.', '']
# 0.08460373548712771
# ["To date can not be greater than employee's relieving date.", 'Өнөөдрийг хүртэл ажилтны чөлөөлөгдсөн өдрөөс илүү байж болохгүй.', '']
# 0.08470469459868753
# ["Payroll date can not be greater than employee's relieving date.", 'Цалингийн огноо нь ажилтны чөлөөлөгдсөн өдрөөс илүү байж болохгүй.', '']
# 0.08480565371024736
# ['Condition and formula', 'Нөхцөл ба томъёо', '']

# %%
print(row)
# Out:
# ['Only Allow Edit For', '', '']
