# %%
import csv
import googletrans

row = []
# Import the CSV file
with open("mn.csv", "r") as csvfile:
    reader = csv.reader(csvfile, delimiter=",")

    # Create a translator object
    translator = googletrans.Translator()

    # Iterate over the rows in the CSV file
    for i,row in enumerate(reader):
        # Get the English word from the first column
        english_word = row[0]

        # Translate the English word to Mongolian
        mongolian_translation = translator.translate(english_word, dest="mn")

        # Add the Mongolian translation to the second column
        row[1] =(mongolian_translation.text)
        print(i/9905)
        print(row)

        # Write the updated CSV file
        with open("new.csv", "a", newline="") as csvfile:
            writer = csv.writer(csvfile, delimiter=",", escapechar="\\")
            writer.writerow(row)
# Out:
# 0.0
# ['Delayed Order Report', 'Хойшлогдсон захиалгын тайлан', '']
# 0.00010095911155981827
# ['Delivered Items To Be Billed', 'Төлбөр тооцох хүргэсэн бараа', '']
# 0.00020191822311963655
# ['Delivery Note Trends', 'Хүргэлтийн тэмдэглэлийн чиг хандлага', '']
# 0.00030287733467945484
# ['Electronic Invoice Register', 'Цахим нэхэмжлэхийн бүртгэл', '']
# 0.0004038364462392731
# ['Employee Advance Summary', 'Ажилчдын урьдчилгаа хураангуй', '']
# 0.0005047955577990914
# ['Employee Billing Summary', 'Ажилчдын тооцооны хураангуй', '']
# 0.0006057546693589097
# ['Employee Birthday', 'Ажилтны төрсөн өдөр', '']
# 0.0007067137809187279
# ['Employee Information', 'Ажилтны мэдээлэл', '']
# 0.0008076728924785462
# ['Employee Leave Balance', 'Ажилтны чөлөөний үлдэгдэл', '']
# 0.0009086320040383645
# ['Employee Leave Balance Summary', 'Ажилтны чөлөөний үлдэгдлийн хураангуй', '']
# 0.0010095911155981827
# ['Employees working on a holiday', 'Амралтын өдрөөр ажилладаг ажилчид', '']
# 0.001110550227158001
# ['Eway Bill', 'Эвей Билл', '']
# 0.0012115093387178194
# ['Expiring Memberships', 'Гишүүнчлэлийн хугацаа дуусч байна', '']
# 0.0013124684502776375
# ['Fichier des Ecritures Comptables [FEC]', 'Нягтлан бодох бүртгэлийн бичилтийн файл [FEC]', '']
# 0.0014134275618374558
# ['Final Assessment Grades', 'Эцсийн үнэлгээний үнэлгээ', '']
# 0.001514386673397274
# ['Fixed Asset Register', 'Үндсэн хөрөнгийн бүртгэл', '']
# 0.0016153457849570924
# ['Gross and Net Profit Report', 'Нийт ба цэвэр ашгийн тайлан', '']
# 0.0017163048965169107
# ['GST Itemised Purchase Register', 'GST-ийн зүйлчилсэн худалдан авалтын бүртгэл', '']
# 0.001817264008076729
# ['GST Itemised Sales Register', 'GST-ийн зүйлчилсэн борлуулалтын бүртгэл', '']
# 0.0019182231196365471
# ['GST Purchase Register', 'GST худалдан авалтын бүртгэл', '']
# 0.0020191822311963654
# ['GST Sales Register', 'GST борлуулалтын бүртгэл', '']
# 0.0021201413427561835
# ['GSTR-1', 'Гастер-1', '']
# 0.002221100454316002
# ['GSTR-2', 'Гастер-2', '']
# 0.00232205956587582
# ['Hotel Room Occupancy', 'Зочид буудлын өрөөний ачаалал', '']
# 0.0024230186774356387
# ['HSN-wise-summary of outward supplies', 'Гадна нийлүүлэлтийн HSN-мэргэн-хураангуй', '']
# 0.002523977788995457
# ['Inactive Customers', 'Идэвхгүй үйлчлүүлэгчид', '']
# 0.002624936900555275
# ['Inactive Sales Items', 'Борлуулалтын идэвхгүй зүйлс', '']
# 0.0027258960121150934
# ['IRS 1099', 'IRS 1099', '']
# 0.0028268551236749115
# ['Issued Items Against Work Order', 'Ажлын захиалгын эсрэг гаргасан зүйлс', '']
# 0.00292781423523473
# ['Projected Quantity as Source', 'Төлөвлөсөн тоо хэмжээ', '']
# 0.003028773346794548
# ['Item Balance (Simple)', 'Барааны үлдэгдэл (Энгийн)', '']
# 0.0031297324583543663
# ['Item Price Stock', 'Барааны үнийн хувьцаа', '']
# 0.003230691569914185
# ['Item Prices', 'Барааны үнэ', '']
# 0.003331650681474003
# ['Item Shortage Report', 'Барааны хомсдлын тайлан', '']
# 0.0034326097930338214
# ['Item Variant Details', 'Барааны хувилбарын дэлгэрэнгүй мэдээлэл', '']
# 0.0035335689045936395
# ['Item-wise Price List Rate', 'Барааны үнийн жагсаалтын хувь', '']
# 0.003634528016153458
# ['Item-wise Purchase History', 'Худалдан авалтын түүх', '']
# 0.003735487127713276
# ['Item-wise Purchase Register', 'Барааны хувьд худалдан авалтын бүртгэл', '']
# 0.0038364462392730943
# ['Item-wise Sales History', 'Бараа бүтээгдэхүүний борлуулалтын түүх', '']
# 0.003937405350832913
# ['Item-wise Sales Register', 'Бараа бүтээгдэхүүний борлуулалтын бүртгэл', '']
# 0.004038364462392731
# ['Items To Be Requested', 'Хүсэх зүйлс', '']
# 0.004139323573952549
# ['Reserved', 'Захиалагдсан', '']
# 0.004240282685512367
# ['Itemwise Recommended Reorder Level', 'Зүйлийн дагуу санал болгож буй дахин эрэмбэлэх түвшин', '']
# 0.004341241797072186
# ['Lead Details', 'Тэргүүлэх дэлгэрэнгүй мэдээлэл', '']
# 0.004442200908632004
# ['Lead Owner Efficiency', 'Тэргүүлэх эзэмшигчийн үр ашиг', '']
# 0.004543160020191822
# ['Loan Repayment and Closure', 'Зээлийн эргэн төлөлт ба хаалт', '']
# 0.00464411913175164
# ['Loan Security Status', 'Зээлийн аюулгүй байдлын байдал', '']
# 0.0047450782433114585
# ['Lost Opportunity', 'Алдагдсан боломж', '']
# 0.004846037354871277
# ['Maintenance Schedules', 'Засвар үйлчилгээний хуваарь', '']
# 0.0049469964664310955
# ['Material Requests for which Supplier Quotations are not created', 'Нийлүүлэгчийн үнийн санал үүсгээгүй материалын хүсэлт', '']
# 0.005047955577990914
# ['Monthly Attendance Sheet', 'Сар бүрийн ирцийн хуудас', '']
# 0.005148914689550732
# ['Open Work Orders', 'Нээлттэй ажлын захиалга', '']
# 0.00524987380111055
# ['Qty to Deliver', 'Хүргүүлэх тоо', '']
# 0.005350832912670369
# ['Patient Appointment Analytics', 'Өвчтөний томилгооны аналитик', '']
# 0.005451792024230187
# ['Payment Period Based On Invoice Date', 'Нэхэмжлэхийн огноог үндэслэн төлбөрийн хугацаа', '']
# 0.005552751135790005
# ['Pending SO Items For Purchase Request', 'Худалдан авах хүсэлт гаргах хүлээгдэж буй SO зүйлс', '']
# 0.005653710247349823
# ['Procurement Tracker', 'Худалдан авалтын хянагч', '']
# 0.005754669358909641
# ['Product Bundle Balance', 'Бүтээгдэхүүний багцын үлдэгдэл', '']
# 0.00585562847046946
# ['Production Analytics', 'Үйлдвэрлэлийн аналитик', '']
# 0.005956587582029278
# ['Profit and Loss Statement', 'Ашиг алдагдлын тайлан', '']
# 0.006057546693589096
# ['Profitability Analysis', 'Ашигт ажиллагааны шинжилгээ', '']
# 0.0061585058051489144
# ['Project Billing Summary', 'Төслийн тооцооны хураангуй', '']
# 0.0062594649167087325
# ['Project wise Stock Tracking', 'Төслийн ухаалаг хувьцааг хянах', '']
# 0.0063604240282685515
# ['Project wise Stock Tracking ', 'Төслийн ухаалаг хувьцааг хянах', '']
# 0.00646138313982837
# ['Prospects Engaged But Not Converted', 'Оролцсон боловч хөрвүүлээгүй хэтийн төлөв', '']
# 0.006562342251388188
# ['Purchase Analytics', 'Худалдан авалтын аналитик', '']
# 0.006663301362948006
# ['Purchase Invoice Trends', 'Худалдан авалтын нэхэмжлэхийн чиг хандлага', '']
# 0.006764260474507825
# ['Qty to Receive', 'Хүлээн авах тоо', '']
# 0.006865219586067643
# ['Received Qty Amount', 'Хүлээн авсан тоо хэмжээ', '']
# 0.006966178697627461
# ['Billed Qty', 'Тооцооны тоо', '']
# 0.007067137809187279
# ['Purchase Order Trends', 'Худалдан авах захиалгын чиг хандлага', '']
# 0.007168096920747097
# ['Purchase Receipt Trends', 'Худалдан авалтын баримтын чиг хандлага', '']
# 0.007269056032306916
# ['Purchase Register', 'Худалдан авалтын бүртгэл', '']
# 0.007370015143866734
# ['Quotation Trends', 'Үнийн саналын чиг хандлага', '']
# 0.007470974255426552
# ['Received Items To Be Billed', 'Төлбөр тооцохоор хүлээн авсан зүйлс', '']
# 0.00757193336698637
# ['Qty to Order', 'Захиалга өгөх тоо', '']
# 0.0076728924785461885
# ['Requested Items To Be Transferred', 'Шилжүүлэхийг хүссэн зүйлс', '']
# 0.0077738515901060075
# ['Qty to Transfer', 'Шилжүүлэх тоо', '']
# 0.007874810701665826
# ['Salary Register', 'Цалингийн бүртгэл', '']
# 0.007975769813225644
# ['Sales Analytics', 'Борлуулалтын аналитик', '']
# 0.008076728924785462
# ['Sales Invoice Trends', 'Борлуулалтын нэхэмжлэхийн чиг хандлага', '']
# 0.00817768803634528
# ['Sales Order Trends', 'Борлуулалтын захиалгын чиг хандлага', '']
# 0.008278647147905098
# ['Sales Partner Commission Summary', 'Борлуулалтын түншийн комиссын хураангуй', '']
# 0.008379606259464916
# ['Sales Partner Target Variance based on Item Group', 'Барааны бүлэгт суурилсан борлуулалтын түншийн зорилтот зөрүү', '']
# 0.008480565371024734
# ['Sales Partner Transaction Summary', 'Борлуулалтын түншийн гүйлгээний хураангуй', '']
# 0.008581524482584554
# ['Sales Partners Commission', 'Борлуулалтын түншүүдийн комисс', '']
# 0.008682483594144372
# ['Invoiced Amount (Exclusive Tax)', 'Нэхэмжлэхийн дүн (Онцгой татвар)', '']
# 0.00878344270570419
# ['Average Commission Rate', 'Комиссын дундаж хувь', '']
# 0.008884401817264008
# ['Sales Payment Summary', 'Борлуулалтын төлбөрийн хураангуй', '']
# 0.008985360928823826
# ['Sales Person Commission Summary', 'Борлуулалтын ажилтны комиссын хураангуй', '']
# 0.009086320040383645
# ['Sales Person Target Variance Based On Item Group', 'Барааны бүлэгт суурилсан борлуулалтын ажилтан зорилтот зөрүү', '']
# 0.009187279151943463
# ['Sales Person-wise Transaction Summary', 'Борлуулалтын ажилтны гүйлгээний хураангуй', '']
# 0.00928823826350328
# ['Sales Register', 'Борлуулалтын бүртгэл', '']
# 0.009389197375063099
# ['Serial No Service Contract Expiry', 'Цуврал Үйлчилгээний гэрээний хугацаа дуусна', '']
# 0.009490156486622917
# ['Serial No Status', 'Цуврал дугаарын статус', '']
# 0.009591115598182737
# ['Serial No Warranty Expiry', 'Цуврал Үгүй Баталгаат хугацаа дуусах', '']
# 0.009692074709742555
# ['Stock Ageing', 'Хувьцааны хөгшрөлт', '']
# 0.009793033821302373
# ['Stock and Account Value Comparison', 'Хувьцааны болон дансны үнийн харьцуулалт', '']
# 0.009893992932862191
# ['Stock Projected Qty', 'Төлөвлөсөн хувьцааны тоо', '']
# 0.009994952044422009
# ['Student and Guardian Contact Details', 'Оюутан, асран хамгаалагчийн холбоо барих мэдээлэл', '']
# 0.010095911155981827
# ['Student Batch-Wise Attendance', 'Оюутны ирц', '']
# 0.010196870267541645
# ['Student Fee Collection', 'Оюутны төлбөр хураах', '']
# 0.010297829379101463
# ['Student Monthly Attendance Sheet', 'Оюутны сарын ирцийн хуудас', '']
# 0.010398788490661282
# ['Subcontracted Item To Be Received', 'Туслан гүйцэтгэгчээр хүлээн авах бараа', '']
# 0.0104997476022211
# ['Subcontracted Raw Materials To Be Transferred', 'Туслан гүйцэтгэгчээр дамжуулан шилжүүлэх түүхий эд', '']
# 0.01060070671378092
# ['Supplier Ledger Summary', 'Нийлүүлэгчийн дэвтэрийн хураангуй', '']
# 0.010701665825340738
# ['Supplier-Wise Sales Analytics', 'Нийлүүлэгчийн ухаалаг борлуулалтын аналитик', '']
# 0.010802624936900556
# ['Support Hour Distribution', 'Дэмжлэгийн цагийн хуваарилалт', '']
# 0.010903584048460374
# ['TDS Computation Summary', 'TDS тооцооллын хураангуй', '']
# 0.011004543160020192
# ['TDS Payable Monthly', 'TDS сар бүр төлөх', '']
# 0.01110550227158001
# ['Territory Target Variance Based On Item Group', 'Зүйлийн бүлэгт үндэслэсэн нутаг дэвсгэрийн зорилтот зөрүү', '']
# 0.011206461383139828
# ['Territory-wise Sales', 'Нутаг дэвсгэрийн хувьд борлуулалт', '']
# 0.011307420494699646
# ['Total Stock Summary', 'Нийт хувьцааны хураангуй', '']
# 0.011408379606259464
# ['Trial Balance', 'Туршилтын үлдэгдэл', '']
# 0.011509338717819282
# ['Trial Balance (Simple)', 'Туршилтын үлдэгдэл (Энгийн)', '']
# 0.011610297829379102
# ['Trial Balance for Party', 'Намын туршилтын үлдэгдэл', '']
# 0.01171125694093892
# ['Unpaid Expense Claim', 'Төлөгдөөгүй зардлын нэхэмжлэл', '']
# 0.011812216052498738
# ['Warehouse wise Item Balance Age and Value', 'Агуулахын ухаалаг Барааны үлдэгдэл Нас ба үнэ цэнэ', '']
# 0.011913175164058556
# ['Work Order Stock Report', 'Ажлын захиалгын хувьцааны тайлан', '']
# 0.012014134275618375
# ['Work Orders in Progress', 'Ажиллаж буй ажлын захиалга', '']
# 0.012115093387178193
# ['Validation Error', 'Баталгаажуулалтын алдаа', '']
# 0.01221605249873801
# ['Automatically Process Deferred Accounting Entry', 'Хойшлогдсон нягтлан бодох бүртгэлийн бичилтийг автоматаар боловсруулах', '']
# 0.012317011610297829
# ['Bank Clearance', 'Банкны төлбөр тооцоо', '']
# 0.012417970721857647
# ['Bank Clearance Detail', 'Банкны төлбөр тооцооны дэлгэрэнгүй', '']
# 0.012518929833417465
# ['Update Cost Center Name / Number', 'Зардлын төвийн нэр / дугаарыг шинэчлэх', '']
# 0.012619888944977285
# ['Journal Entry Template', 'Тэмдэглэлийн бүртгэлийн загвар', '']
# 0.012720848056537103
# ['Template Title', 'Загварын гарчиг', '']
# 0.012821807168096921
# ['Journal Entry Type', 'Өдрийн тэмдэглэлийн төрөл', '']
# 0.01292276627965674
# ['Journal Entry Template Account', 'Тэмдэглэлийн бүртгэлийн загвар данс', '']
# 0.013023725391216557
# ['Process Deferred Accounting', 'Хойшлогдсон нягтлан бодох бүртгэлийн үйл явц', '']
# 0.013124684502776375
# ['Manual entry cannot be created! Disable automatic entry for deferred accounting in accounts settings and try again', 'Гараар оруулга үүсгэх боломжгүй! Бүртгэлийн тохиргооноос хойшлогдсон бүртгэлийн автомат оруулгыг идэвхгүй болгоод дахин оролдоно уу', '']
# 0.013225643614336193
# ['End date cannot be before start date', 'Дуусах огноо эхлэх өдрөөс өмнө байж болохгүй', '']
# 0.013326602725896012
# ['Total Counts Targeted', 'Зорилтот нийт тоо', '']
# 0.01342756183745583
# ['Total Counts Completed', 'Дууссан нийт тоо', '']
# 0.01352852094901565
# ['Counts Targeted: {0}', 'Зорилтот тоо: {0}', '']
# 0.013629480060575468
# ['Payment Account is mandatory', 'Төлбөрийн данс заавал байх ёстой', '']
# 0.013730439172135286
# ["If checked,,\nDisbursement Details,,\nMaterial Request Warehouse,,\nSelect warehouse for material requests,,\nTransfer Materials For Warehouse {0},,\nProduction Plan Material Request Warehouse,,\nSets 'Source Warehouse' in each row of the items table.,,\nSets 'Target Warehouse' in each row of the items table.,,\nShow Cancelled Entries,,\nBackdated Stock Entry,,\nRow #{}: Currency of {} - {} doesn't matches company currency.,,\n{} Assets created for {},,\n{0} Number {1} is already used in {2} {3},,\nUpdate Bank Clearance Dates,,\nHealthcare Practitioner: ,,\nLab Test Conducted: ,,\nLab Test Event: ,,\nLab Test Result: ,,\nClinical Procedure conducted: ,,\nTherapy Session Charges: {0},,\nTherapy: ,,\nTherapy Plan: ,,\nTotal Counts Targeted: ,,\nTotal Counts Completed: ,,\nAndaman and Nicobar Islands,,\nAndhra Pradesh,,\nArunachal Pradesh,,\nAssam,,\nBihar,,\nChandigarh,,\nChhattisgarh,,\nDadra and Nagar Haveli,,\nDaman and Diu,,\nDelhi,,\nGoa,,\nGujarat,,\nHaryana,,\nHimachal Pradesh,,\nJammu and Kashmir,,\nJharkhand,,\nKarnataka,,\nKerala,,\nLakshadweep Islands,,\nMadhya Pradesh,,\nMaharashtra,,\nManipur,,\nMeghalaya,,\nMizoram,,\nNagaland,,\nOdisha,,\nOther Territory,,\nPondicherry,,\nPunjab,,\nRajasthan,,\nSikkim,,\nTamil Nadu,,\nTelangana,,\nTripura,,\nUttar Pradesh,,\nUttarakhand,,\nWest Bengal,,\nIs Mandatory,,\nPublished on,,\nService Received But Not Billed,,\nDeferred Accounting Settings,,\nBook Deferred Entries Based On,,\nDays,,\nMonths,,\nBook Deferred Entries Via Journal Entry,,\nSubmit Journal Entries,,\nIf this is unchecked Journal Entries will be saved in a Draft state and will have to be submitted manually,,\nEnable Distributed Cost Center,,\nDistributed Cost Center,,\nDunning,,\nDUNN-.MM.-.YY.-,,\nOverdue Days,,\nDunning Type,,\nDunning Fee,,\nDunning Amount,,\nResolved,,\nUnresolved,,\nPrinting Setting,,\nBody Text,,\nClosing Text,,\nResolve,,\nDunning Letter Text,,\nIs Default Language,,\nLetter or Email Body Text,,\nLetter or Email Closing Text,,\nBody and Closing Text Help,,\nOverdue Interval,,\nDunning Letter,,\nThis section allows the user to set the Body and Closing text of the Dunning Letter for the Dunning Type based on language", 'Хэрэв шалгасан бол,\nТөлбөрийн дэлгэрэнгүй мэдээлэл,\nМатериалын хүсэлтийн агуулах,,\nМатериалын хүсэлтийн агуулах сонгох,\nАгуулахад материал шилжүүлэх {0},,\nҮйлдвэрлэлийн төлөвлөгөөний материал Хүсэлтийн агуулах,,\nХүснэгтийн мөр бүрт \'Source Warehouse\'-г тохируулна.,,\nХүснэгтийн мөр бүрт "Зорилтот агуулах"-ыг тохируулна.,,\nЦуцлагдсан оруулгуудыг харуулах,,\nХугацаа хоцрогдсон хувьцааны бүртгэл,,\nМөр #{}: {} - {} валют нь компанийн мөнгөн тэмдэгттэй таарахгүй байна.,,\n{} {}-д зориулж үүсгэсэн хөрөнгө,,\n{0} {1} дугаарыг аль хэдийн {2} {3}-д ашигласан,,\nБанкны төлбөр тооцооны огноог шинэчлэх,,\nЭрүүл мэндийн эмч: ,,\nЛабораторийн туршилт хийсэн: ,,\nЛабораторийн туршилтын арга хэмжээ: ,,\nЛабораторийн шинжилгээний үр дүн: ,,\nХийсэн эмнэлзүйн процедур: ,,\nЭмчилгээний төлбөр: {0},,\nЭмчилгээ: ,,\nЭмчилгээний төлөвлөгөө: ,,\nЗорилтот нийт тоо: ,,\nГүйцэтгэсэн нийт тоо: ,,\nАндаман ба Никобар арлууд,\nАндхра Прадеш,,\nАруначал Прадеш,,\nАссам,,\nБихар,,\nЧандигарх,,\nЧхаттисгарх,,\nДадра, Нагар Хавели нар,\nДаман, Диу нар,\nДели,,\nГоа,,\nГужарат,,\nХарьяна,,\nХимачал Прадеш,,\nЖамму ба Кашмир,\nЖарханд,,\nКарнатака,,\nКерала,,\nЛакшадвип арлууд,,\nМадхья Прадеш,,\nМахараштра,,\nМанипур,,\nМегалая,,\nМизорам,,\nНагаланд,,\nОдиша,,\nБусад нутаг дэвсгэр,,\nPondicherry,,\nПенжаб,,\nРажастан,,\nСикким,,\nТамил Наду,,\nТелангана,,\nТрипура,,\nУттар Прадеш,,\nУттаракханд,,\nБаруун Бенгал,,\nЗаавал байна,,\nНийтэлсэн,,\nҮйлчилгээг хүлээн авсан боловч төлбөр тооцоогүй,\nНягтлан бодох бүртгэлийн хойшлуулсан тохиргоо,,\n,, дээр үндэслэн хойшлогдсон бүртгэлийг захиалах\nӨдөр,,\nСар,,\nХойшлогдсон бүртгэлийг сэтгүүлийн бичилтээр захиалах,,\nТэмдэглэлийн бичилт оруулах,,\nХэрэв үүнийг сонгоогүй бол сэтгүүлийн бичилтүүд ноорог төлөвт хадгалагдах бөгөөд гараар оруулах шаардлагатай ...
# 0.013831398283695104
# ['Reference Detail No', 'Лавлагааны дэлгэрэнгүй дугаар', '']
# 0.013932357395254922
# ['Custom Remarks', 'Захиалгат тайлбар', '']
# 0.01403331650681474
# ['Please select a Company first.', 'Эхлээд компаниа сонгоно уу.', '']
# 0.014134275618374558
# ['Row #{0}: Reference Document Type must be one of Sales Order,,\nPOS Closing Entry,,\nPOS Opening Entry,,\nPOS Transactions,,\nPOS Closing Entry Detail,,\nOpening Amount,,\nClosing Amount,,\nPOS Closing Entry Taxes,,\nPOS Invoice,,\nACC-PSINV-.YYYY.-,,\nConsolidated Sales Invoice,,\nReturn Against POS Invoice,,\nConsolidated,,\nPOS Invoice Item,,\nPOS Invoice Merge Log,,\nPOS Invoices,,\nConsolidated Credit Note,,\nPOS Invoice Reference,,\nSet Posting Date,,\nOpening Balance Details,,\nPOS Opening Entry Detail,,\nPOS Payment Method,,\nPayment Methods,,\nProcess Statement Of Accounts,,\nGeneral Ledger Filters,,\nCustomers,,\nSelect Customers By,,\nFetch Customers,,\nSend To Primary Contact,,\nPrint Preferences,,\nInclude Ageing Summary,,\nEnable Auto Email,,\nFilter Duration (Months),,\nCC To,,\nHelp Text,,\nEmails Queued,,\nProcess Statement Of Accounts Customer,,\nBilling Email,,\nPrimary Contact Email,,\nPSOA Cost Center,,\nPSOA Project,,\nACC-PINV-RET-.YYYY.-,,\nSupplier GSTIN,,\nPlace of Supply,,\nSelect Billing Address,,\nGST Details,,\nGST Category,,\nRegistered Regular,,\nRegistered Composition,,\nUnregistered,,\nSEZ,,\nOverseas,,\nUIN Holders,,\nWith Payment of Tax,,\nWithout Payment of Tax,,\nInvoice Copy,,\nOriginal for Recipient,,\nDuplicate for Transporter,,\nDuplicate for Supplier,,\nTriplicate for Supplier,,\nReverse Charge,,\nY,,\nN,,\nE-commerce GSTIN,,\nReason For Issuing document,,\n01-Sales Return,,\n02-Post Sale Discount,,\n03-Deficiency in services,,\n04-Correction in Invoice,,\n05-Change in POS,,\n06-Finalization of Provisional assessment,,\n07-Others,,\nEligibility For ITC,,\nInput Service Distributor,,\nImport Of Service,,\nImport Of Capital Goods,,\nIneligible,,\nAll Other ITC,,\nAvailed ITC Integrated Tax,,\nAvailed ITC Central Tax,,\nAvailed ITC State/UT Tax,,\nAvailed ITC Cess,,\nIs Nil Rated or Exempted,,\nIs Non GST,,\nACC-SINV-RET-.YYYY.-,,\nE-Way Bill No.,,\nIs Consolidated,,\nBilling Address GSTIN,,\nCustomer GSTIN,,\nGST Transporter ID,,\nDistance (in km),,\nRoad,,\nAir,,\nRail,,\nShip,,\nGST Vehicle Type,,\nOver Dimensional Cargo (ODC),,\nConsumer,,\nDeemed Export,,\nPort Code,,\n Shipping Bill Number,,\nShipping Bill Date,,\nSubscription End Date,,\nFollow Calendar Months,,\nIf this is checked subsequent new invoices will be created on calendar  month and quarter start dates irrespective of current invoice start date,,\nGenerate New Invoices Past Due Date,,\nNew invoices will be generated as per schedule even if current invoices are unpaid or past due date,,\nDocument Type ,,\nSubscription Price Based On,,\nFixed Rate,,\nBased On Price List,,\nMonthly Rate,,\nCancel Subscription After Grace Period,,\nSource State,,\nIs Inter State,,\nPurchase Details,,\nDepreciation Posting Date,,\nBy default', 'Мөр #{0}: Лавлах баримт бичгийн төрөл нь Борлуулалтын захиалгын аль нэг байх ёстой,,\nПосын хаалтын бүртгэл,,\nПосын нээлтийн бүртгэл,,\nПОС-ын гүйлгээ,,\nПосын хаалтын бүртгэлийн дэлгэрэнгүй мэдээлэл,,\nНээлтийн дүн,,\nХаалтын дүн,,\nПОС-ын хаалтын татвар,,\nПОС-ын нэхэмжлэх,,\nACC-PSINV-.YYYY.-,,\nБорлуулалтын нэгдсэн нэхэмжлэх,,\nПОС-ын нэхэмжлэхийн эсрэг буцаах,,\nНэгдсэн,,\nПОС-ын нэхэмжлэхийн зүйл,,\nПОС-ын нэхэмжлэх нэгтгэх бүртгэл,,\nПОС-ын нэхэмжлэх,,\nЗээлийн нэгдсэн тэмдэглэл,,\nПОС-ын нэхэмжлэхийн лавлагаа,\nНийтэлсэн огноог тохируулах,,\nНээлтийн үлдэгдэл дэлгэрэнгүй,,\nПосын нээлтийн бүртгэлийн дэлгэрэнгүй мэдээлэл,,\nPOS төлбөрийн арга,,\nТөлбөрийн арга,,\nДансны үйл явцын тайлан,,\nЕрөнхий дэвтрийн шүүлтүүр,,\nҮйлчлүүлэгчид,,\nХарилцагчдыг сонгох,,\nХарилцагчдыг татах,,\nҮндсэн харилцагч руу илгээх,,\nХэвлэх тохиргоо,,\nХөгшрөлтийн хураангуйг оруулах,,\nАвтомат имэйлийг идэвхжүүлэх,,\nШүүлтүүрийн үргэлжлэх хугацаа (сар),\nCC To,,\nТусламжийн текст,,\nДараалалд орсон имэйлүүд,,\nҮйлчлүүлэгчийн дансны тайлан,,\nТооцооны имэйл,,\nАнхдагч холбоо барих имэйл,,\nPSOA зардлын төв,,\nPSOA төсөл,,\nACC-PINV-RET-.YYYY.-,,\nНийлүүлэгч GSTIN,,\nНийлүүлэлтийн газар,,\nТооцооны хаяг сонгох,,\nGST  ...
# 0.014235234729934376
# [" choose the 'Naming Series' option.", '"Нэрлэх цуврал" сонголтыг сонгоно уу.', '']
# 0.014336193841494194
# ['Configure the default Price List when creating a new Purchase transaction. Item prices will be fetched from this Price List.', 'Худалдан авалтын шинэ гүйлгээ үүсгэхдээ өгөгдмөл үнийн жагсаалтыг тохируулна уу. Барааны үнийг энэ үнийн жагсаалтаас авах болно.', '']
# 0.014437152953054012
# ["If this option is configured 'Yes',,\nIf this option is configured 'Yes'", 'Хэрэв энэ сонголтыг "Тийм" гэж тохируулсан бол,\nХэрэв энэ сонголтыг "Тийм" гэж тохируулсан бол', '']
# 0.014538112064613832
# ['Quantity & Stock', 'Тоо хэмжээ ба нөөц', '']
# 0.01463907117617365
# ['Call Details', 'Дуудлагын дэлгэрэнгүй мэдээлэл', '']
# 0.014740030287733468
# ['Authorised By', 'Зөвшөөрөгдсөн', '']
# 0.014840989399293287
# ['Signee (Company)', 'Бүртгэгч (Компани)', '']
# 0.014941948510853105
# ['Signed By (Company)', 'Гарын үсэг зурсан (Компани)', '']
# 0.015042907622412923
# ['First Response Time', 'Эхний хариу өгөх хугацаа', '']
# 0.01514386673397274
# ['Request For Quotation', 'Үнийн санал авах хүсэлт', '']
# 0.015244825845532559
# ['Opportunity Lost Reason Detail', 'Боломж алдагдсан шалтгааны дэлгэрэнгүй', '']
# 0.015345784957092377
# ['Access Token Secret', 'Токен нууцад нэвтрэх', '']
# 0.015446744068652195
# ['Add to Topics', 'Сэдвүүдэд нэмэх', '']
# 0.015547703180212015
# ['...Adding Article to Topics', '...Сэдвүүдэд нийтлэл нэмэх', '']
# 0.015648662291771833
# ['Add Article to Topics', 'Сэдвүүдэд нийтлэл нэмэх', '']
# 0.01574962140333165
# ['This article is already added to the existing topics', 'Энэ нийтлэлийг одоо байгаа сэдвүүдэд аль хэдийн нэмсэн', '']
# 0.01585058051489147
# ['Add to Programs', 'Програмд \u200b\u200bнэмэх', '']
# 0.015951539626451287
# ['Programs', 'Програмууд', '']
# 0.016052498738011105
# ['...Adding Course to Programs', '...Хөтөлбөрт хичээл нэмэх', '']
# 0.016153457849570924
# ['Add Course to Programs', 'Хөтөлбөрт курс нэмэх', '']
# 0.01625441696113074
# ['This course is already added to the existing programs', 'Энэ курс нь одоо байгаа хөтөлбөрүүдэд аль хэдийн нэмэгдсэн байна', '']
# 0.01635537607269056
# ['Learning Management System Settings', 'Сургалтын удирдлагын системийн тохиргоо', '']
# 0.016456335184250378
# ['Enable Learning Management System', 'Сургалтын удирдлагын системийг идэвхжүүлэх', '']
# 0.016557294295810196
# ['Learning Management System Title', 'Сургалтын удирдлагын системийн гарчиг', '']
# 0.016658253407370014
# ['...Adding Quiz to Topics', '...Сэдвүүдэд асуулт хариулт нэмж байна', '']
# 0.016759212518929832
# ['Add Quiz to Topics', 'Сэдвүүдэд шалгалт нэмэх', '']
# 0.01686017163048965
# ['This quiz is already added to the existing topics', 'Энэ асуулт хариултыг одоо байгаа сэдвүүдэд аль хэдийн нэмсэн', '']
# 0.01696113074204947
# ['Enable Admission Application', 'Элсэлтийн програмыг идэвхжүүлнэ үү', '']
# 0.01706208985360929
# ['EDU-ATT-.YYYY.-', 'EDU-ATT-.YYYY.-', '']
# 0.017163048965169108
# ['Marking attendance', 'Ирцийг тэмдэглэх', '']
# 0.017264008076728926
# ['Add Guardians to Email Group', 'И-мэйл группт асран хамгаалагч нэмнэ үү', '']
# 0.017364967188288744
# ['Attendance Based On', 'Ирц дээр үндэслэнэ', '']
# 0.017465926299848562
# ['Check this to mark the student as present in case the student is not attending the institute to participate or represent the institute in any event.\\n\\n', 'Оюутан институтэд ямар нэгэн арга хэмжээнд оролцох эсвэл институтийг төлөөлөхөөр ирээгүй тохиолдолд түүнийг байгаа гэж тэмдэглэхийн тулд үүнийг шалгана уу.\\n\\n', '']
# 0.01756688541140838
# ['Add to Courses', 'Курсуудад нэмэх', '']
# 0.0176678445229682
# ['...Adding Topic to Courses', '...Хичээлүүдэд сэдэв нэмэх', '']
# 0.017768803634528017
# ['Add Topic to Courses', 'Хичээлүүдэд сэдэв нэмэх', '']
# 0.017869762746087835
# ['This topic is already added to the existing courses', 'Энэ сэдвийг одоо байгаа курсуудад аль хэдийн нэмсэн', '']
# 0.017970721857647653
# ['If Shopify does not have a customer in the order,,\nThe accounts are set by the system automatically but do confirm these defaults,,\nDefault Round Off Account,,\nFailed Import Log,,\nFixed Error Log,,\nCompany {0} already exists. Continuing will overwrite the Company and Chart of Accounts,,\nMeta Data,,\nUnresolve,,\nCreate Document,,\nMark as unresolved,,\nTaxJar Settings,,\nSandbox Mode,,\nEnable Tax Calculation,,\nCreate TaxJar Transaction,,\nCredentials,,\nLive API Key,,\nSandbox API Key,,\nConfiguration,,\nTax Account Head,,\nShipping Account Head,,\nPractitioner Name,,\nEnter a name for the Clinical Procedure Template,,\nSet the Item Code which will be used for billing the Clinical Procedure.,,\nSelect an Item Group for the Clinical Procedure Item.,,\nClinical Procedure Rate,,\nCheck this if the Clinical Procedure is billable and also set the rate.,,\nCheck this if the Clinical Procedure utilises consumables. Click ,,\n to know more,,\nYou can also set the Medical Department for the template. After saving the document', 'Хэрэв Shopify захиалгад үйлчлүүлэгчгүй бол,\nБүртгэлүүдийг систем автоматаар тохируулдаг боловч эдгээр өгөгдмөлүүдийг баталгаажуулна,,\nҮндсэн тойргийн данс,,\nАмжилтгүй импортын бүртгэл,,\nТогтмол алдааны бүртгэл,,\n{0} компани аль хэдийн байна. Үргэлжлүүлбэл Компани болон Дансны төлөвлөгөөг дарж бичнэ,,\nМета өгөгдөл,,\nШийдвэрлэхгүй,,\nБаримт бичиг үүсгэх,,\nШийдвэрлэгдээгүй гэж тэмдэглэх,,\nTaxJar тохиргоо,,\nSandbox горим,,\nТатвар тооцооллыг идэвхжүүлэх,,\nTaxJar гүйлгээ үүсгэх,,\nИтгэмжлэх жуух бичиг,,\nLive API түлхүүр,,\nSandbox API түлхүүр,,\nТохиргоо,,\nТатварын дансны дарга,\nХүргэлтийн дансны дарга,,\nДадлагажигч нэр,,\nЭмнэлзүйн процедурын загварт нэр оруулна уу,\nЭмнэлзүйн процедурын төлбөр тооцоонд ашиглагдах зүйлийн кодыг тохируулна уу.,,\nЭмнэлзүйн процедурын зүйлийн бүлгийг сонгоно уу.,,\nЭмнэлзүйн процедурын хурд,,\nХэрэв Клиникийн процедур нь төлбөр төлөх боломжтой бол үүнийг шалгаж, мөн хувь хэмжээг тогтооно уу.,,\nЭмнэлзүйн процедур нь хэрэглээний материалыг ашиглаж байгаа бол үүнийг шалгана уу. ,, дарна уу\n илүү ихийг мэдэхийн тулд,,\nТа мөн загварт зориулж Эрүүл мэндийн хэлтсийг тохируулж болно. Баримт бичгийг хадгалсны дараа', '']
# 0.01807168096920747
# ['Descriptive Test Result', 'Дүрслэх туршилтын үр дүн', '']
# 0.01817264008076729
# ['Allow Blank', 'Хоосон байхыг зөвшөөрөх', '']
# 0.018273599192327107
# ['Descriptive Test Template', 'Дүрслэх тестийн загвар', '']
# 0.018374558303886925
# ['If you want to track Payroll and other HRMS operations for a Practitoner,,\nSet the Practitioner Schedule you just created. This will be used while booking appointments.,,\nCreate a service item for Out Patient Consulting.,,\nIf this Healthcare Practitioner works for the In-Patient Department', 'Хэрэв та дадлага хийгчийн цалин хөлс болон бусад HRMS үйл ажиллагааг хянахыг хүсвэл,\nДөнгөж үүсгэсэн эмчийн хуваариа тохируулна уу. Үүнийг цаг захиалах үед ашиглана.,,\nOut Patient Consulting үйлчилгээний зүйл үүсгэх.,,\nХэрэв энэ эмч хэвтэн эмчлүүлэх тасагт ажилладаг бол', '']
# 0.018475517415446743
# ['Set the Out Patient Consulting Charge for this Practitioner.', 'Энэ эмчийн өвчтөнд зөвлөгөө өгөх төлбөрийг тогтоо.', '']
# 0.01857647652700656
# ['If this Healthcare Practitioner also works for the In-Patient Department,,\nIf checked', 'Хэрэв энэ эмч мөн хэвтэн эмчлүүлэх тасагт ажилладаг бол,\nХэрэв шалгасан бол', '']
# 0.01867743563856638
# ['Collect Registration Fee', 'Бүртгэлийн хураамж авах', '']
# 0.018778394750126198
# ['If your Healthcare facility bills registrations of Patients,,\nChecking this will automatically create a Sales Invoice whenever an appointment is booked for a Patient.,,\nHealthcare Service Items,,\nYou can create a service item for Inpatient Visit Charge and set it here. Similarly', 'Хэрэв танай эрүүл мэндийн байгууллага өвчтөний бүртгэлийг төлдөг бол,\nҮүнийг шалгаснаар өвчтөнд цаг товлох бүрд автоматаар борлуулалтын нэхэмжлэх үүсгэнэ.,,\nЭрүүл мэндийн үйлчилгээний зүйлс,,\nТа хэвтэн эмчлүүлэх үйлчилгээний төлбөрийг үүсгэж, энд тохируулж болно. Үүнтэй адил', '']
# 0.018879353861686016
# ['Set up default Accounts for the Healthcare Facility', 'Эрүүл мэндийн байгууллагын өгөгдмөл дансуудыг тохируулна уу', '']
# 0.018980312973245834
# ['If you wish to override default accounts settings and configure the Income and Receivable accounts for Healthcare,,\nOut Patient SMS alerts,,\nIf you want to send SMS alert on Patient Registration', 'Хэрэв та өгөгдмөл дансны тохиргоог хүчингүй болгож, эрүүл мэндийн үйлчилгээний орлого, авлагын дансыг тохируулахыг хүсвэл,\nӨвчтөнөөс гарах SMS дохио,,\nХэрэв та өвчтөний бүртгэлийн талаар SMS дохио илгээхийг хүсвэл', '']
# 0.019081272084805655
# ['Admission Order Details', 'Элсэлтийн захиалгын дэлгэрэнгүй мэдээлэл', '']
# 0.019182231196365473
# ['Admission Ordered For', 'Элсэлтийн захиалга өгсөн', '']
# 0.01928319030792529
# ['Expected Length of Stay', 'Хүлээгдэж буй оршин суух хугацаа', '']
# 0.01938414941948511
# ['Admission Service Unit Type', 'Элсэлтийн үйлчилгээний нэгжийн төрөл', '']
# 0.019485108531044928
# ['Healthcare Practitioner (Primary)', 'Эрүүл мэндийн эмч (Анхан шатны)', '']
# 0.019586067642604746
# ['Healthcare Practitioner (Secondary)', 'Эрүүл мэндийн эмч (хоёрдогч)', '']
# 0.019687026754164564
# ['Admission Instruction', 'Элсэлтийн заавар', '']
# 0.019787985865724382
# ['Chief Complaint', 'Гол гомдол', '']
# 0.0198889449772842
# ['Medications', 'Эмийн бэлдмэл', '']
# 0.019989904088844018
# ['Investigations', 'Мөрдөн байцаалтын ажиллагаа', '']
# 0.020090863200403836
# ['Discharge Detials', 'Буулгах дэлгэрэнгүй мэдээлэл', '']
# 0.020191822311963654
# ['Discharge Ordered Date', 'Захиалга өгсөн огноо', '']
# 0.020292781423523473
# ['Discharge Instructions', 'Буулгах заавар', '']
# 0.02039374053508329
# ['Follow Up Date', 'Дагах огноо', '']
# 0.02049469964664311
# ['Discharge Notes', 'Цутгах тэмдэглэл', '']
# 0.020595658758202927
# ['Processing Inpatient Discharge', 'Эмнэлэгт хэвтэн эмчлүүлж буй эмнэлгээс гарах', '']
# 0.020696617869762745
# ['Processing Patient Admission', 'Өвчтөний хүлээн авалтыг боловсруулж байна', '']
# 0.020797576981322563
# ['Check-in time cannot be greater than the current time', 'Бүртгүүлэх цаг нь одоогийн цагаас илүү байж болохгүй', '']
# 0.02089853609288238
# ['Process Transfer', 'Процесс дамжуулах', '']
# 0.0209994952044422
# ['HLC-LAB-.YYYY.-', 'HLC-LAB-.YYYY.-', '']
# 0.02110045431600202
# ['Expected Result Date', 'Хүлээгдэж буй үр дүнгийн огноо', '']
# 0.02120141342756184
# ['Expected Result Time', 'Хүлээгдэж буй үр дүнгийн хугацаа', '']
# 0.021302372539121657
# ['Printed on', 'Хэвлэсэн', '']
# 0.021403331650681475
# ['Requesting Practitioner', 'Дадлагажигчийг хүсэх', '']
# 0.021504290762241293
# ['Requesting Department', 'Хүсэлт гаргах хэлтэс', '']
# 0.02160524987380111
# ['Employee (Lab Technician)', 'Ажилтан (Лабораторийн техникч)', '']
# 0.02170620898536093
# ['Lab Technician Name', 'Лабораторийн техникчийн нэр', '']
# 0.021807168096920748
# ['Lab Technician Designation', 'Лабораторийн техникчийн тодорхойлолт', '']
# 0.021908127208480566
# ['Compound Test Result', 'Нийлмэл туршилтын үр дүн', '']
# 0.022009086320040384
# ['Organism Test Result', 'Организмын шинжилгээний үр дүн', '']
# 0.022110045431600202
# ['Sensitivity Test Result', 'Мэдрэмжийн тестийн үр дүн', '']
# 0.02221100454316002
# ['Worksheet Print', 'Ажлын хуудас хэвлэх', '']
# 0.022311963654719838
# ['Worksheet Instructions', 'Ажлын хуудасны заавар', '']
# 0.022412922766279656
# ['Result Legend Print', 'Үр дүнгийн домог хэвлэх', '']
# 0.022513881877839474
# ['Print Position', 'Хэвлэх байрлал', '']
# 0.022614840989399292
# ['Bottom', 'Доод талд', '']
# 0.02271580010095911
# ['Top', 'Топ', '']
# 0.02281675921251893
# ['Both', 'Хоёулаа', '']
# 0.022917718324078747
# ['Result Legend', 'Үр дүнгийн домог', '']
# 0.023018677435638565
# ['Lab Tests', 'Лабораторийн туршилтууд', '']
# 0.023119636547198386
# ['No Lab Tests found for the Patient {0}', 'Өвчтөнд зориулсан лабораторийн шинжилгээ олдсонгүй {0}', '']
# 0.023220595658758204
# ['Did not send SMS', 'SMS илгээгээгүй', '']
# 0.023321554770318022
# ['No Lab Tests created', 'Лабораторийн шинжилгээ үүсгээгүй', '']
# 0.02342251388187784
# ['Creating Lab Tests...', 'Лабораторийн тест үүсгэж байна...', '']
# 0.02352347299343766
# ['Lab Test Group Template', 'Лабораторийн туршилтын бүлгийн загвар', '']
# 0.023624432104997477
# ['Add New Line', 'Шинэ мөр нэмэх', '']
# 0.023725391216557295
# ['Secondary UOM', 'Хоёрдогч UOM', '']
# 0.023826350328117113
# ['<b>Single</b>: Results which require only a single input.\\n<br>\\n<b>Compound</b>: Results which require multiple event inputs.\\n<br>\\n<b>Descriptive</b>: Tests which have multiple result components with manual result entry.\\n<br>\\n<b>Grouped</b>: Test templates which are a group of other test\ntemplates.\\n<br>\\n<b>No Result</b>: Tests with no results,,\nIf unchecked', '<b>Ганц</b>: Зөвхөн нэг оролт шаарддаг илэрцүүд.\\n<br>\\n<b>Нэгдэл</b>: Олон үйл явдлын оролт шаарддаг илэрцүүд.\\n<br>\\n<b> Дүрслэх</b>: Гараар үр дүнг оруулах олон үр дүнгийн бүрэлдэхүүн хэсэгтэй тестүүд.\\n<br>\\n<b>Бүлэглэсэн</b>: Бусад тестийн бүлэг болох тестийн загварууд\nзагварууд.\\n<br>\\n<b>Үр дүнгүй</b>: Үр дүнгүй туршилтууд,,\nСонголтгүй бол', '']
# 0.02392730943967693
# ['Description ', 'Тодорхойлолт', '']
# 0.02402826855123675
# ['Descriptive Test', 'Дүрслэх тест', '']
# 0.024129227662796567
# ['Group Tests', 'Бүлгийн тестүүд', '']
# 0.024230186774356385
# ['Instructions to be printed on the worksheet', 'Ажлын хуудсан дээр хэвлэх заавар', '']
# 0.024331145885916203
# ['Information to help easily interpret the test report,,\nNormal Test Result,,\nSecondary UOM Result,,\nItalic,,\nUnderline,,\nOrganism,,\nOrganism Test Item,,\nColony Population,,\nColony UOM,,\nTobacco Consumption (Past),,\nTobacco Consumption (Present),,\nAlcohol Consumption (Past),,\nAlcohol Consumption (Present),,\nBilling Item,,\nMedical Codes,,\nClinical Procedures,,\nOrder Admission,,\nScheduling Patient Admission,,\nOrder Discharge,,\nSample Details,,\nCollected On,,\nNo. of prints,,\nNumber of prints required for labelling the samples,,\nHLC-VTS-.YYYY.-,,\nIn Time,,\nOut Time,,\nPayroll Cost Center,,\nApprovers,,\nThe first Approver in the list will be set as the default Approver.,,\nShift Request Approver,,\nPAN Number,,\nProvident Fund Account,,\nMICR Code,,\nRepay unclaimed amount from salary,,\nDeduction from salary,,\nExpired Leaves,,\nReference No,,\nHaircut percentage is the percentage difference between market value of the Loan Security and the value ascribed to that Loan Security when used as collateral for that loan.,,\nLoan To Value Ratio expresses the ratio of the loan amount to the value of the security pledged. A loan security shortfall will be triggered if this falls below the specified value for any loan ,,\nIf this is not checked the loan by default will be considered as a Demand Loan,,\nThis account is used for booking loan repayments from the borrower and also disbursing loans to the borrower,,\nThis account is capital account which is used to allocate capital for loan disbursal account ,,\nThis account will be used for booking loan interest accruals,,\nThis account will be used for booking penalties levied due to delayed repayments,,\nVariant BOM,,\nTemplate Item,,\nSelect template item,,\nSelect variant item code for the template item {0},,\nDowntime Entry,,\nDT-,,\nWorkstation / Machine,,\nOperator,,\nIn Mins,,\nDowntime Reason,,\nStop Reason,,\nExcessive machine set up time,,\nUnplanned machine maintenance,,\nOn-machine press checks,,\nMachine operator errors,,\nMachine malfunction,,\nElectricity down,,\nOperation Row Number,,\nOperation {0} added multiple times in the work order {1},,\nIf ticked', 'Туршилтын тайланг хялбархан тайлбарлахад туслах мэдээлэл,\nТуршилтын хэвийн үр дүн,,\nХоёрдогч UOM үр дүн,,\nНалуу,,\nДоогуур зураас,,\nОрганизм,,\nОрганизмын тестийн зүйл,,\nКолонийн хүн ам,,\nКолони UOM,,\nТамхины хэрэглээ (өнгөрсөн),\nТамхины хэрэглээ (одоогоор),\nАрхины хэрэглээ (өнгөрсөн),\nАрхины хэрэглээ (одоогоор),\nТооцооны зүйл,,\nЭмнэлгийн кодууд,,\nЭмнэлзүйн процедур,,\nЗахиалга авах,,\nӨвчтөнийг хүлээн авах хуваарь гаргах,\nЗахиалга гаргах,,\nЖишээ дэлгэрэнгүй мэдээлэл,,\nЦуглуулсан ,,\nХэвлэлийн тоо,,\nДээжийг шошголоход шаардагдах хэвлэлийн тоо,,\nHLC-VTS-.YYYY.-,,\nЦагтаа,,\nГадагш цаг,,\nЦалингийн зардлын төв,,\nЗөвшөөрөгчид,,\nЖагсаалтын эхний Зөвшөөрөгчийг өгөгдмөл Зөвшөөрөгчөөр тохируулах болно.,,\nШилжилтийн хүсэлтийг баталгаажуулагч,,\nPAN дугаар,,\nПровидент сангийн данс,,\nMICR код,,\nЦалингаас нэхэмжлээгүй мөнгийг буцаан олгох,,\nЦалингаас суутгал хийх,,\nХугацаа нь дууссан навч,,\nЛавлагааны дугаар,,\nҮс засах хувь гэдэг нь Зээлийн баталгааны зах зээлийн үнэ болон тухайн зээлийн барьцаанд ашигласан үнийн зөрүү юм.,,\nЗээлийн үнийн харьцаа нь зээлийн дүнг барьцаалсан үнэт цаасны үнэд харьцуулсан харьцааг илэрхийлдэг. Хэрэв энэ нь аливаа зээлийн заасан хэмжээнээс доогуур байвал зээлийн баталгааны хомсдол үүснэ,\nҮүнийг шалгахгүй бол анхдагчаар зээлийг Эрэлттэй зээл гэж үзнэ,\nЭнэ данс нь зээлдэгчийн зээлийн эргэн төлөлтийг захиалах, мөн зээлдэгчид зээл олгоход ашиглагддаг.\nЭнэ данс нь хөрөнгийн данс бөгөөд зээл олгох дансанд хөрөнгө хуваарилахад ашиглагддаг.\nЭнэ данс нь зээлийн хүүгийн хуримтлалыг захиалахад ашиглагдана,\nЭнэ дансыг эргэн төлөлт хойшлогдсоны улмаас авах торгуулийн захиалгын төлбөрт ашиглах болно,\nВариант Монголбанк,,\nЗагварын зүйл,,\nЗагварын зүйлийг сонгох,,\nЗагварын зүйлийн кодыг сонгоно уу {0},,\nСул зогсолтын бүртгэл,,\nDT-,,\nАжлын станц / Машин,,\n ...
# 0.02443210499747602
# ['Backflush Raw Materials', 'Буцах түүхий эд', '']
# 0.02453306410903584
# ["The Stock Entry of type 'Manufacture' is known as backflush. Raw materials being consumed to manufacture finished goods is known as backflushing. <br><br> When creating Manufacture Entry,,\nWork In Progress Warehouse,,\nThis Warehouse will be auto-updated in the Work In Progress Warehouse field of Work Orders.,,\nFinished Goods Warehouse,,\nThis Warehouse will be auto-updated in the Target Warehouse field of Work Order.,,\nIf ticked", '"Үйлдвэрлэл" төрлийн хувьцааны бичилтийг буцаах гэж нэрлэдэг. Бэлэн бүтээгдэхүүн үйлдвэрлэхэд хэрэглэж буй түүхий эдийг буцаан угаах гэж нэрлэдэг. <br><br> Үйлдвэрлэлийн бүртгэл үүсгэх үед,\nАжиллаж байгаа агуулах,,\nЭнэхүү агуулах нь Ажлын захиалгын "Ажил явагдаж буй агуулах" талбарт автоматаар шинэчлэгдэх болно.,,\nБэлэн бүтээгдэхүүний агуулах,,\nЭнэхүү агуулах нь Ажлын захиалгын Зорилтот агуулах хэсэгт автоматаар шинэчлэгдэх болно.,,\nХэрэв тэмдэглэсэн бол', '']
# 0.024634023220595658
# ['Source Warehouses (Optional)', 'Эх сурвалжийн агуулахууд (заавал биш)', '']
# 0.024734982332155476
# ['System will pickup the materials from the selected warehouses. If not specified,,\nLead Time,,\nPAN Details,,\nCreate Customer,,\nInvoicing,,\nEnable Auto Invoicing,,\nSend Membership Acknowledgement,,\nSend Invoice with Email,,\nMembership Print Format,,\nInvoice Print Format,,\nRevoke <Key></Key>,,\nYou can learn more about memberships in the manual. ,,\nERPNext Docs,,\nRegenerate Webhook Secret,,\nGenerate Webhook Secret,,\nCopy Webhook URL,,\nLinked Item,,\nIs Recurring,,\nHRA Exemption,,\nMonthly House Rent,,\nRented in Metro City,,\nHRA as per Salary Structure,,\nAnnual HRA Exemption,,\nMonthly HRA Exemption,,\nHouse Rent Payment Amount,,\nRented From Date,,\nRented To Date,,\nMonthly Eligible Amount,,\nTotal Eligible HRA Exemption,,\nValidating Employee Attendance...,,\nSubmitting Salary Slips and creating Journal Entry...,,\nCalculate Payroll Working Days Based On,,\nConsider Unmarked Attendance As,,\nFraction of Daily Salary for Half Day,,\nComponent Type,,\nProvident Fund,,\nAdditional Provident Fund,,\nProvident Fund Loan,,\nProfessional Tax,,\nIs Income Tax Component,,\nComponent properties and references ,,\nAdditional Salary ,,\nUnmarked days,,\nAbsent Days,,\nConditions and Formula variable and example,,\nFeedback By,,\nManufacturing Section,,\nBy default', 'Систем нь сонгосон агуулахаас материалыг авах болно. Хэрэв заагаагүй бол,\nБоловсруулах хугацаа,,\nPAN дэлгэрэнгүй,,\nХэрэглэгч үүсгэх,,\nНэхэмжлэх,,\nАвтомат нэхэмжлэхийг идэвхжүүлэх,,\nГишүүнчлэлээ илгээх,,\nНэхэмжлэхийг имэйлээр илгээх,,\nГишүүнчлэлийн хэвлэх формат,,\nНэхэмжлэх хэвлэх формат,,\n<Түлхүүр></түлхүүр>-ийг хүчингүй болгох,,\nТа гарын авлагаас гишүүнчлэлийн талаар илүү ихийг мэдэж болно. ,,\nERPNext Docs,,\nWebhook нууцыг сэргээх,,\nWebhook нууц үүсгэх,,\nWebhook URL-г хуулах,,\nХолбоотой зүйл,,\nДахин давтагдаж байна,,\nHRA чөлөөлөх,,\nСарын түрээс,,\nМетро хотод түрээслүүлнэ,,\nЦалингийн бүтцийн дагуу HRA,\nЖилийн Хүний нөөцийн үнэлгээний чөлөөлөлт,,\nСар бүр Хүний нөөцийн үнэлгээний хөнгөлөлт,\nБайрны түрээсийн төлбөрийн хэмжээ,,\nогнооноос хойш түрээсэлсэн,,\nӨнөөдрийг хүртэл түрээсэлсэн,,\nСарын зөвшөөрөгдсөн хэмжээ,,\nНийт эрх бүхий HRA чөлөөлөлт,,\nАжилчдын ирцийг баталгаажуулж байна...,,\nЦалингийн хуудас өгөх, журналын бичилт хийх...,,\nЦалингийн ажлын өдрүүдийг үндэслэн тооцоолно,,\nТэмдэглэгдээгүй ирцийг,,\nХагас өдрийн өдрийн цалингийн хэсэг,,\nБүрэлдэхүүн хэсгийн төрөл,,\nПровидент сан,,\nНэмэлт тусламжийн сан,,\nПровидент сангийн зээл,,\nМэргэжлийн татвар,,\nОрлогын татварын бүрэлдэхүүн хэсэг,,\nБүрэлдэхүүн хэсгүүдийн шинж чанарууд ба лавлагаа,\nНэмэлт цалин,,\nТэмдэглэгдээгүй өдрүүд,,\nЭзгүй өдрүүд,,\nНөхцөл ба томъёоны хувьсагч ба жишээ,\nСанал хүсэлт,,\nҮйлдвэрлэлийн хэсэг,,\nАнхны утгаараа', '']
# 0.024835941443715294
# ['Configure the default Price List when creating a new Sales transaction. Item prices will be fetched from this Price List.', 'Борлуулалтын шинэ гүйлгээ үүсгэх үед анхдагч үнийн жагсаалтыг тохируулна уу. Барааны үнийг энэ үнийн жагсаалтаас авах болно.', '']
# 0.024936900555275112
# ["If this option is configured 'Yes',,\nIf this option is configured 'Yes'", 'Хэрэв энэ сонголтыг "Тийм" гэж тохируулсан бол,\nХэрэв энэ сонголтыг "Тийм" гэж тохируулсан бол', '']
# 0.02503785966683493
# ['Default Warehouse for Sales Return', 'Борлуулалтын буцаах өгөгдмөл агуулах', '']
# 0.02513881877839475
# ['Default In Transit Warehouse', 'Транзит агуулахын өгөгдмөл', '']
# 0.02523977788995457
# ['Enable Perpetual Inventory For Non Stock Items', 'Хувьцааны бус бараа материалын байнгын бүртгэлийг идэвхжүүлэх', '']
# 0.025340737001514388
# ['HRA Settings', 'HRA тохиргоо', '']
# 0.025441696113074206
# ['Basic Component', 'Үндсэн бүрэлдэхүүн хэсэг', '']
# 0.025542655224634024
# ['HRA Component', 'HRA бүрэлдэхүүн хэсэг', '']
# 0.025643614336193842
# ['Arrear Component', 'Хоцрогдсон бүрэлдэхүүн хэсэг', '']
# 0.02574457344775366
# ['Please enter the company name to confirm', 'Баталгаажуулахын тулд компанийн нэрийг оруулна уу', '']
# 0.02584553255931348
# ['Quotation Lost Reason Detail', 'Үнийн санал алдагдсан шалтгааны дэлгэрэнгүй', '']
# 0.025946491670873296
# ['Enable Variants', 'Хувилбаруудыг идэвхжүүлнэ үү', '']
# 0.026047450782433115
# ['Save Quotations as Draft', 'Үнийн саналыг ноорог болгон хадгалах', '']
# 0.026148409893992933
# ['MAT-DN-RET-.YYYY.-', 'MAT-DN-RET-.YYYY.-', '']
# 0.02624936900555275
# ['Please Select a Customer', 'Хэрэглэгчээ сонгоно уу', '']
# 0.02635032811711257
# ['Against Delivery Note Item', 'Хүргэлтийн тэмдэглэлийн эсрэг', '']
# 0.026451287228672387
# ['Is Non GST ', 'GST биш', '']
# 0.026552246340232205
# ['Image Description', 'Зургийн тайлбар', '']
# 0.026653205451792023
# ['Transfer Status', 'Шилжүүлгийн статус', '']
# 0.02675416456335184
# ['MAT-PR-RET-.YYYY.-', 'MAT-PR-RET-.YYYY.-', '']
# 0.02685512367491166
# ['Track this Purchase Receipt against any Project', 'Энэхүү худалдан авалтын баримтыг аливаа төслийн эсрэг хянах', '']
# 0.026956082786471477
# ['Please Select a Supplier', 'Нийлүүлэгчээ сонгоно уу', '']
# 0.0270570418980313
# ['Add to Transit', 'Нийтийн тээвэрт нэмэх', '']
# 0.027158001009591117
# ['Set Basic Rate Manually', 'Үндсэн ханшийг гараар тохируулах', '']
# 0.027258960121150935
# ['By default,,\nSet a Default Warehouse for Inventory Transactions. This will be fetched into the Default Warehouse in the Item master.,,\nThis will allow stock items to be displayed in negative values. Using this option depends on your use case. With this option unchecked', 'Анхны утгаараа,,\nБараа материалын гүйлгээний үндсэн агуулахыг тохируулах. Үүнийг Барааны мастер дахь Өгөгдмөл агуулах руу оруулах болно.,,\nЭнэ нь хувьцааны зүйлсийг сөрөг утгаар харуулах боломжийг олгоно. Энэ сонголтыг ашиглах нь таны ашиглалтаас хамаарна. Энэ сонголтыг сонгоогүй тохиолдолд', '']
# 0.027359919232710753
# ['Choose between FIFO and Moving Average Valuation Methods. Click ', 'FIFO болон Хөдөлгөөнт дундаж үнэлгээний аргуудаас сонгоно уу. дарна уу', '']
# 0.02746087834427057
# [' to know more about them.', 'тэдний талаар илүү ихийг мэдэх.', '']
# 0.02756183745583039
# ["Show 'Scan Barcode' field above every child table to insert Items with ease.", "Зүйлүүдийг хялбархан оруулахын тулд хүүхдийн хүснэгт бүрийн дээр 'Баркод скан хийх' талбарыг харуул.", '']
# 0.027662796567390208
# ['Serial numbers for stock will be set automatically based on the Items entered based on first in first out in transactions like Purchase/Sales Invoices,,\nIf blank', 'Худалдан авалт/борлуулалтын нэхэмжлэх,,,,\nХэрэв хоосон бол', '']
# 0.027763755678950026
# ['Service Level Agreement Details', 'Үйлчилгээний түвшний гэрээний дэлгэрэнгүй мэдээлэл', '']
# 0.027864714790509844
# ['Service Level Agreement Status', 'Үйлчилгээний түвшний гэрээний төлөв', '']
# 0.027965673902069662
# ['On Hold Since', 'Хүлээсэн цагаас хойш', '']
# 0.02806663301362948
# ['Total Hold Time', 'Нийт барих хугацаа', '']
# 0.028167592125189298
# ['Response Details', 'Хариултын дэлгэрэнгүй мэдээлэл', '']
# 0.028268551236749116
# ['Average Response Time', 'Хариу өгөх дундаж хугацаа', '']
# 0.028369510348308934
# ['User Resolution Time', 'Хэрэглэгчийн шийдвэрлэх хугацаа', '']
# 0.028470469459868752
# ['SLA is on hold since {0}', 'SLA {0}-с хойш зогссон', '']
# 0.02857142857142857
# ['Pause SLA On Status', 'Статус дээр SLA түр зогсоох', '']
# 0.02867238768298839
# ['Pause SLA On', 'SLA-г түр зогсоох', '']
# 0.028773346794548207
# ['Greetings Section', 'Мэндчилгээний хэсэг', '']
# 0.028874305906108025
# ['Greeting Title', 'Мэндчилгээний гарчиг', '']
# 0.028975265017667843
# ['Greeting Subtitle', 'Мэндчилгээний хадмал орчуулга', '']
# 0.029076224129227664
# ['Youtube ID', 'Youtube ID', '']
# 0.029177183240787483
# ['Youtube Statistics', 'Youtube-ийн статистик', '']
# 0.0292781423523473
# ['Views', 'Үзсэн тоо', '']
# 0.02937910146390712
# ['Dislikes', 'Дислекси', '']
# 0.029480060575466937
# ['Video Settings', 'Видео тохиргоо', '']
# 0.029581019687026755
# ['Enable YouTube Tracking', 'YouTube Tracking-г идэвхжүүлнэ үү', '']
# 0.029681978798586573
# ['30 mins', '30 минут', '']
# 0.02978293791014639
# ['1 hr', '1 цаг', '']
# 0.02988389702170621
# ['6 hrs', '6 цаг', '']
# 0.029984856133266027
# ['Patient Progress', 'Өвчтөний ахиц дэвшил', '']
# 0.030085815244825845
# ['Targetted', 'Зорилтот', '']
# 0.030186774356385664
# ['Score Obtained', 'Авсан оноо', '']
# 0.03028773346794548
# ['Sessions', 'Хурал', '']
# 0.0303886925795053
# ['Average Score', 'Дундаж оноо', '']
# 0.030489651691065118
# ['Select Assessment Template', 'Үнэлгээний загварыг сонгоно уу', '']
# 0.030590610802624936
# [' out of ', '-аас', '']
# 0.030691569914184754
# ['Select Assessment Parameter', 'Үнэлгээний параметрийг сонгоно уу', '']
# 0.030792529025744572
# ['Gender: ', 'Хүйс:', '']
# 0.03089348813730439
# ['Contact: ', 'Холбоо барих:', '']
# 0.03099444724886421
# ['Total Therapy Sessions: ', 'Нийт эмчилгээний сесс:', '']
# 0.03109540636042403
# ['Monthly Therapy Sessions: ', 'Сар бүрийн эмчилгээний хуралдаанууд:', '']
# 0.031196365471983848
# ['Patient Profile', 'Өвчтөний танилцуулга', '']
# 0.031297324583543666
# ['Point Of Sale', 'Борлуулалтын цэг', '']
# 0.03139828369510348
# ['Email sent successfully.', 'Имэйлийг амжилттай илгээсэн.', '']
# 0.0314992428066633
# ['Search by invoice id or customer name', 'Нэхэмжлэхийн дугаар эсвэл хэрэглэгчийн нэрээр хайх', '']
# 0.03160020191822312
# ['Invoice Status', 'Нэхэмжлэхийн төлөв', '']
# 0.03170116102978294
# ['Filter by invoice status', 'Нэхэмжлэлийн төлөвөөр шүүх', '']
# 0.03180212014134275
# ['Select item group', 'Зүйлийн бүлгийг сонгоно уу', '']
# ...
# 0.05623422513881878
# ['Payment amount cannot be less than or equal to 0', 'Төлбөрийн хэмжээ 0-ээс бага эсвэл тэнцүү байж болохгүй', '']
# 0.056335184250378596
# ['Please enter the phone number first', 'Эхлээд утасны дугаараа оруулна уу', '']
# 0.05643614336193842
# ['Row #{}: {} {} does not exist.', 'Мөр #{}: {} {} байхгүй байна.', '']
# 0.05653710247349823
# ['Row #{0}: {1} is required to create the Opening {2} Invoices', 'Мөр #{0}: Нээлтийн {2} нэхэмжлэх үүсгэхийн тулд {1} шаардлагатай', '']
# 0.056638061585058054
# ['You had {} errors while creating opening invoices. Check {} for more details', 'Нээлтийн нэхэмжлэх үүсгэх явцад танд {} алдаа гарсан. Дэлгэрэнгүй мэдээллийг {}-г шалгана уу', '']
# 0.05673902069661787
# ['Error Occured', 'Алдаа гарлаа', '']
# 0.05683997980817769
# ['Opening Invoice Creation In Progress', 'Нэхэмжлэхийг нээж байна', '']
# 0.056940938919737505
# ['Creating {} out of {} {}', '{} {}-с {} үүсгэж байна', '']
# 0.057041898031297326
# ["(Serial No: {0}) cannot be consumed as it's reserverd to fullfill Sales Order {1}.", '(Серийн дугаар: {0}) Борлуулалтын захиалгыг {1} биелүүлэхээр нөөцөлсөн тул хэрэглэх боломжгүй.', '']
# 0.05714285714285714
# ['Item {0} {1}', '{0} {1} зүйл', '']
# 0.05724381625441696
# ['Last Stock Transaction for item {0} under warehouse {1} was on {2}.', '{1} агуулахын {0} барааны сүүлийн хувьцааны гүйлгээ {2}-д хийгдсэн.', '']
# 0.05734477536597678
# ['Stock Transactions for Item {0} under warehouse {1} cannot be posted before this time.', '{1} агуулахын {0} барааны хувьцааны гүйлгээг энэ хугацаанаас өмнө нийтлэх боломжгүй.', '']
# 0.0574457344775366
# ['Posting future stock transactions are not allowed due to Immutable Ledger', 'Ирээдүйн хувьцааны гүйлгээг өөрчлөх боломжгүй дэвтэрийн улмаас нийтлэхийг хориглоно', '']
# 0.05754669358909641
# ['A BOM with name {0} already exists for item {1}.', '{1} зүйлд {0} нэртэй BOM аль хэдийн байна.', '']
# 0.057647652700656235
# ['{0}{1} Did you rename the item? Please contact Administrator / Tech support', '{0}{1} Та зүйлийн нэрийг өөрчилсөн үү? Администратор / Техникийн дэмжлэгтэй холбоо барина уу', '']
# 0.05774861181221605
# ['At row #{0}: the sequence id {1} cannot be less than previous row sequence id {2}', '№{0} мөрөнд: дарааллын id {1} нь өмнөх мөрийн id {2}-ээс бага байж болохгүй.', '']
# 0.05784957092377587
# ['The {0} ({1}) must be equal to {2} ({3})', '{0} ({1}) нь {2} ({3})-тай тэнцүү байх ёстой', '']
# 0.057950530035335686
# ["{0},,\nCannot ensure delivery by Serial No as Item {0} is added with and without Ensure Delivery by Serial No.,,\nItem {0} has no Serial No. Only serilialized items can have delivery based on Serial No,,\nNo active BOM found for item {0}. Delivery by Serial No cannot be ensured,,\nNo pending medication orders found for selected criteria,,\nFrom Date cannot be after the current date.,,\nTo Date cannot be after the current date.,,\nFrom Time cannot be after the current time.,,\nTo Time cannot be after the current time.,,\nStock Entry {0} created and ,,\nInpatient Medication Orders updated successfully,,\nRow {0}: Cannot create Inpatient Medication Entry against cancelled Inpatient Medication Order {1},,\nRow {0}: This Medication Order is already marked as completed,,\nQuantity not available for {0} in warehouse {1},,\nPlease enable Allow Negative Stock in Stock Settings or create Stock Entry to proceed.,,\nNo Inpatient Record found against patient {0},,\nAn Inpatient Medication Order {0} against Patient Encounter {1} already exists.,,\nAllow In Returns,,\nHide Unavailable Items,,\nApply Discount on Discounted Rate,,\nTherapy Plan Template,,\nFetching Template Details,,\nLinked Item Details,,\nTherapy Types,,\nTherapy Plan Template Detail,,\nNon Conformance,,\nProcess Owner,,\nCorrective Action,,\nPreventive Action,,\nProblem,,\nResponsible,,\nCompletion By,,\nProcess Owner Full Name,,\nRight Index,,\nLeft Index,,\nSub Procedure,,\nPassed,,\nPrint Receipt,,\nEdit Receipt,,\nFocus on search input,,\nFocus on Item Group filter,,\nCheckout Order / Submit Order / New Order,,\nAdd Order Discount,,\nItem Code: {0} is not available under warehouse {1}.,,\nSerial numbers unavailable for Item {0} under warehouse {1}. Please try changing warehouse.,,\nFetched only {0} available serial numbers.,,\nSwitch Between Payment Modes,,\nEnter {0} amount.,,\nYou don't have enough points to redeem.,,\nYou can redeem upto {0}.,,\nEnter amount to be redeemed.,,\nYou cannot redeem more than {0}.,,\nOpen Form View,,\nPOS invoice {0} created succesfully,,\nStock quantity not enough for Item Code: {0} under warehouse {1}. Available quantity {2}.,,\nSerial No: {0} has already been transacted into another POS Invoice.,,\nBalance Serial No,,\nWarehouse: {0} does not belong to {1},,\nPlease select batches for batched item {0},,\nPlease select quantity on row {0},,\nPlease enter serial numbers for serialized item {0},,\nBatch {0} already selected.,,\nPlease select a warehouse to get available quantities,,\nFor transfer from source", '{0},,\n{0}-г нэмсэн, нэмээгүй тул Серийн дугаараар хүргэлтийг баталгаажуулах боломжгүй.\n{0} зүйлд серийн дугаар байхгүй. Зөвхөн цуваажсан барааг Серийн дугаар,,\n{0} зүйлд идэвхтэй ББМ олдсонгүй. Серийн дугаараар хүргэлтийг баталгаажуулах боломжгүй,,\nСонгосон шалгуурын дагуу хүлээгдэж буй эмийн захиалга олдсонгүй,\nОгноо нь одоогийн огнооноос хойш байж болохгүй.,,\nTo Date нь одоогийн огнооноос хойш байж болохгүй.,,\nЦаг хугацаа одоогийн цагаас хойш байж болохгүй.,,\nЦаг хугацаа одоогийн цагаас хойш байж болохгүй.,,\nХувьцааны бүртгэлийг {0} үүсгэсэн ба ,,\nЭмнэлэгт хэвтэн эмчлүүлэх эмийн захиалга амжилттай шинэчлэгдсэн,\nМөр {0}: Цуцлагдсан хэвтүүлэн эмчлэх эмийн захиалга {1}-н эсрэг хэвтүүлэн эмчлэх эмийн бүртгэл үүсгэх боломжгүй,\nМөр {0}: Энэ эмийн захиалгыг аль хэдийн дууссан гэж тэмдэглэсэн байна,,\n{1} агуулахад байгаа {0}-н тоо хэмжээ байхгүй байна,,\nҮргэлжлүүлэхийн тулд Хувьцааны тохиргоонд "Сөрөг хувьцааг зөвшөөрөх"-ийг идэвхжүүлэх эсвэл хувьцааны бүртгэл үүсгэнэ үү.,,\n{0} өвчтөний талаар хэвтэн эмчлүүлэх бүртгэл олдсонгүй,\nӨвчтөнтэй тулгарах {1} эсрэг хэвтүүлэн эмчлэх эмийн захиалга {0} аль хэдийн байна.,,\nБуцааж өгөхийг зөвшөөрөх,,\nБоломжгүй зүйлсийг нуух,,\nХөнгөлөлттэй үнээр хөнгөлөлт үзүүлэх,,\nЭмчилгээний төлөвлөгөөний загвар,,\nЗагварын дэлгэрэнгүй мэдээллийг авч байна,,\nХолбоотой зүйлийн дэлгэрэнгүй мэдээлэл,,\nЭмчилгээний төрлүүд,\nЭмчилгээний төлөвлөгөөний загвар дэлгэрэнгүй,,\nҮл-тохирол,,\nПроцесс эз ...
# 0.05805148914689551
# ['Cannot find Item with this Barcode', 'Энэ зураасан кодтой зүйлийг олж чадсангүй', '']
# 0.05815244825845533
# ['{0} is mandatory. Maybe Currency Exchange record is not created for {1} to {2}', '{0} заавал байх ёстой. {1}-ээс {2} хүртэлх Валютын солилцооны бүртгэл үүсгэгдээгүй байж магадгүй юм.', '']
# 0.058253407370015144
# ['{} has submitted assets linked to it. You need to cancel the assets to create purchase return.', '{} үүнтэй холбоотой хөрөнгийг илгээсэн. Худалдан авалтын өгөөжийг бий болгохын тулд та хөрөнгөө цуцлах хэрэгтэй.', '']
# 0.058354366481574965
# ['Cannot cancel this document as it is linked with submitted asset {0}. Please cancel it to continue.', 'Энэ баримт бичиг нь илгээсэн {0} өмчтэй холбоотой тул цуцлах боломжгүй. Үргэлжлүүлэхийн тулд үүнийг цуцална уу.', '']
# 0.05845532559313478
# ['Row #{}: Serial No. {} has already been transacted into another POS Invoice. Please select valid serial no.', 'Мөр #{}: Серийн дугаар {}-г өөр ПОС-ын нэхэмжлэх рүү шилжүүлсэн байна. Хүчинтэй серийн дугаар сонгоно уу.', '']
# 0.0585562847046946
# ['Row #{}: Serial Nos. {} has already been transacted into another POS Invoice. Please select valid serial no.', 'Мөр #{}: Цуврал дугаар. {} аль хэдийн өөр ПОС-ын нэхэмжлэх рүү шилжүүлсэн байна. Хүчинтэй серийн дугаар сонгоно уу.', '']
# 0.058657243816254416
# ['Item Unavailable', 'Зүйл боломжгүй', '']
# 0.05875820292781424
# ['Row #{}: Serial No {} cannot be returned since it was not transacted in original invoice {}', 'Мөр #{}: Цуваа дугаар {} нь анхны нэхэмжлэх {}-д гүйлгээ хийгдээгүй тул буцаах боломжгүй.', '']
# 0.05885916203937405
# ['Please set default Cash or Bank account in Mode of Payment {}', 'Төлбөрийн горимд бэлэн мөнгө эсвэл банкны дансыг тохируулна уу {}', '']
# 0.058960121150933874
# ['Please set default Cash or Bank account in Mode of Payments {}', 'Төлбөрийн горимд бэлэн мөнгө эсвэл банкны дансыг тохируулна уу {}', '']
# 0.05906108026249369
# ['Please ensure {} account is a Balance Sheet account. You can change the parent account to a Balance Sheet account or select a different account.', '{} данс балансын данс мөн эсэхийг шалгана уу. Та эцэг эхийн дансаа Балансын данс болгон өөрчлөх эсвэл өөр данс сонгох боломжтой.', '']
# 0.05916203937405351
# ['Please ensure {} account is a Payable account. Change the account type to Payable or select a different account.', '{} данс нь Төлбөрийн данс мөн эсэхийг шалгана уу. Дансны төрлийг Төлбөр болгон өөрчлөх эсвэл өөр данс сонгоно уу.', '']
# 0.059262998485613325
# ['Row {}: Expense Head changed to {} ', 'Мөр {}: Зардлын толгойг {} болгож өөрчилсөн', '']
# 0.059363957597173146
# ['because account {} is not linked to warehouse {} ', 'Учир нь {} бүртгэл {} агуулахтай холбогдоогүй байна.', '']
# 0.05946491670873296
# ['or it is not the default inventory account', 'эсвэл энэ нь үндсэн бараа материалын данс биш юм', '']
# 0.05956587582029278
# ['Expense Head Changed', 'Зардлын толгой өөрчлөгдсөн', '']
# 0.0596668349318526
# ['because expense is booked against this account in Purchase Receipt {}', 'Учир нь энэ дансанд зардлууд нь Худалдан авалтын баримт {}-д бичигдсэн байдаг.', '']
# 0.05976779404341242
# ['as no Purchase Receipt is created against Item {}. ', 'Учир нь {} зүйлийн эсрэг Худалдан авалтын баримт байхгүй.', '']
# 0.05986875315497223
# ['This is done to handle accounting for cases when Purchase Receipt is created after Purchase Invoice', 'Энэ нь Худалдан авалтын нэхэмжлэхийн дараа Худалдан авалтын баримт үүссэн тохиолдолд нягтлан бодох бүртгэлийг зохицуулах зорилгоор хийгддэг.', '']
# 0.059969712266532055
# ['Purchase Order Required for item {}', '{} зүйлд худалдан авах захиалга шаардлагатай', '']
# 0.06007067137809187
# ['To submit the invoice without purchase order please set {} ', 'Худалдан авах захиалгагүйгээр нэхэмжлэхийг илгээхийн тулд {}-г тохируулна уу.', '']
# 0.06017163048965169
# ['as {} in {}', 'шиг {}', '']
# 0.06027258960121151
# ['Mandatory Purchase Order', 'Заавал худалдан авах захиалга', '']
# 0.06037354871277133
# ['Purchase Receipt Required for item {}', '{} зүйлд худалдан авалтын баримт шаардлагатай', '']
# 0.06047450782433115
# ['To submit the invoice without purchase receipt please set {} ', 'Худалдан авалтын баримтгүйгээр нэхэмжлэхийг илгээхийн тулд {}-г тохируулна уу.', '']
# 0.06057546693589096
# ['Mandatory Purchase Receipt', 'Заавал худалдан авалт хийсэн баримт', '']
# 0.060676426047450785
# ['POS Profile {} does not belongs to company {}', 'POS профайл {} нь {} компанид харьяалагддаггүй', '']
# 0.0607773851590106
# ['User {} is disabled. Please select valid user/cashier', '{} хэрэглэгч идэвхгүй болсон. Хүчинтэй хэрэглэгч/кассчин сонгоно уу', '']
# 0.06087834427057042
# ['Row #{}: Original Invoice {} of return invoice {} is {}. ', 'Мөр #{}: Буцаах нэхэмжлэхийн {} эх нэхэмжлэх {} байна.', '']
# 0.060979303382130236
# ['Original invoice should be consolidated before or along with the return invoice.', 'Эх нэхэмжлэхийг буцаах нэхэмжлэхийн өмнө эсвэл хамт нэгтгэсэн байх ёстой.', '']
# 0.06108026249369006
# ['You can add original invoice {} manually to proceed.', 'Та үргэлжлүүлэхийн тулд анхны нэхэмжлэх {}-г гараар нэмж болно.', '']
# 0.06118122160524987
# ['Please ensure {} account is a Balance Sheet account. ', '{} данс балансын данс мөн эсэхийг шалгана уу.', '']
# 0.061282180716809694
# ['You can change the parent account to a Balance Sheet account or select a different account.', 'Та эцэг эхийн дансаа Балансын данс болгон өөрчлөх эсвэл өөр данс сонгох боломжтой.', '']
# 0.06138313982836951
# ['Please ensure {} account is a Receivable account. ', '{} данс нь Авлагын данс мөн эсэхийг шалгана уу.', '']
# 0.06148409893992933
# ['Change the account type to Receivable or select a different account.', 'Дансны төрлийг Авлага болгон өөрчлөх эсвэл өөр данс сонгоно уу.', '']
# 0.061585058051489144
# ["{} can't be cancelled since the Loyalty Points earned has been redeemed. First cancel the {} No {}", 'Цуглуулсан үнэнч оноогоо зарцуулсан тул {} цуцлах боломжгүй. Эхлээд {} Үгүй {}-г цуцлах', '']
# 0.061686017163048966
# ['already exists', 'аль хэдийнэ байгаа', '']
# 0.06178697627460878
# ['POS Closing Entry {} against {} between selected period', 'Сонгосон хугацааны хооронд {}-н эсрэг ПОС-ын хаалтын оролт {}', '']
# 0.0618879353861686
# ['POS Invoice is {}', 'ПОС-ын нэхэмжлэх нь {}', '']
# 0.06198889449772842
# ["POS Profile doesn't matches {}", 'Посын профайл {}-тэй таарахгүй байна', '']
# 0.06208985360928824
# ['POS Invoice is not {}', 'ПОС-ын нэхэмжлэх нь {} биш', '']
# 0.06219081272084806
# ["POS Invoice isn't created by user {}", 'ПОС-ын нэхэмжлэхийг хэрэглэгч {} үүсгээгүй', '']
# 0.062291771832407875
# ['Row #{}: {}', 'Мөр #{}: {}', '']
# 0.062392730943967696
# ['Invalid POS Invoices', 'ПОС-ын нэхэмжлэх хүчингүй', '']
# 0.06249369005552751
# ['Please add the account to root level Company - {}', 'Бүртгэлийг үндсэн түвшинд нэмнэ үү Компани - {}', '']
# 0.06259464916708733
# ['While creating account for Child Company {0},,\nAccount Not Found,,\nWhile creating account for Child Company {0}', 'Хүүхдийн компанид бүртгэл үүсгэх явцад {0},,\nБүртгэл олдсонгүй,,\nХүүхдийн компанид бүртгэл үүсгэх үед {0}', '']
# 0.06269560827864715
# ['Please convert the parent account in corresponding child company to a group account.', 'Харгалзах хүүхдийн компани дахь эцэг эхийн дансыг бүлгийн данс руу хөрвүүлнэ үү.', '']
# 0.06279656739020696
# ['Invalid Parent Account', 'Эцэг эхийн данс буруу', '']
# 0.06289752650176679
# ['Renaming it is only allowed via parent company {0},,\nIf you {0} {1} quantities of the item {2}', 'Түүний нэрийг өөрчлөхийг зөвхөн {0} толгой компаниар зөвшөөрнө,,\nХэрэв та {0} {1} зүйлийн тоо хэмжээг {2}', '']
# 0.0629984856133266
# ['If you {0} {1} worth item {2},,\nAs the field {0} is enabled', 'Хэрэв та {0} {1} үнэ цэнэтэй зүйл {2} бол,,\n{0} талбарыг идэвхжүүлсэн тул', '']
# 0.06309944472488642
# ['As the field {0} is enabled,,\nCannot deliver Serial No {0} of item {1} as it is reserved to fullfill Sales Order {2},,\nSales Order {0} has reservation for the item {1}', '{0} талбар идэвхжсэн тул,\nБорлуулалтын захиалгын {2}-г биелүүлэхээр нөөцөлсөн тул {1} зүйлийн {0} дугаарыг хүргэх боломжгүй,\nБорлуулалтын захиалга {0} нь {1} барааны захиалгатай байна.', '']
# 0.06320040383644623
# ['{0} Serial No {1} cannot be delivered', '{0} Цуврал дугаар {1}-г хүргэх боломжгүй', '']
# 0.06330136294800606
# ['Row {0}: Subcontracted Item is mandatory for the raw material {1}', 'Мөр {0}: Туслан гүйцэтгэгч нь түүхий эд {1}-д заавал байх ёстой.', '']
# 0.06340232205956588
# ['As there are sufficient raw materials,,\n If you still want to proceed', 'Түүхий эд хангалттай байгаа тул,\n Хэрэв та үргэлжлүүлэхийг хүсч байвал', '']
# 0.06350328117112569
# ['The item referenced by {0} - {1} is already invoiced', '{0} - {1}-ийн лавласан зүйл аль хэдийн нэхэмжлэгдсэн байна', '']
# 0.0636042402826855
# ['Therapy Session overlaps with {0}', 'Эмчилгээний хуралдаан {0}-тэй давхцаж байна', '']
# 0.06370519939424533
# ['Therapy Sessions Overlapping', 'Эмчилгээний хуралдаанууд давхцаж байна', '']
# 0.06380615850580515
# ['Therapy Plans', 'Эмчилгээний төлөвлөгөө', '']
# 0.06390711761736496
# ['Item Code,,\nGet Items from Material Requests against this Supplier,,\nEnable European Access,,\nCreating Purchase Order ...,,\nSelect a Supplier from the Default Suppliers of the items below. On selection', 'Барааны код,,\nЭнэ ханган нийлүүлэгчийн эсрэг материаллаг хүсэлтээс зүйл авах,,\nЕвропын хандалтыг идэвхжүүлэх,,\nХудалдан авах захиалга үүсгэж байна ...,,\nДоорх зүйлсийн үндсэн нийлүүлэгчээс нийлүүлэгчийг сонгоно уу. Сонголт дээр', '']
# 0.06400807672892478
# ['Row #{}: You must select {} serial numbers for item {}.', 'Мөр #{}: Та {} зүйлд {} серийн дугаар сонгох ёстой.', '']

# %%
print(row)
# Out:
# ['Delayed Order Report', '', '']
